# %% [markdown]
# # ***RUN NOTEBOOK IN ORDER
# # ***Might have to wait a bit between running each cell or PUGREST server will be busy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import re
# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup

#hiding warning messages
import warnings
warnings.filterwarnings("ignore")

#Reading in Summary MERGED CSV
data = pd.read_csv('Final_Merged_Cleaned_CSV_7-1')
data.shape
# Out:
# (8684, 4)

# %% [markdown]
# # Downloading Molecular Formulas

# %%
CID_list = data['PUBCHEM_CID'].tolist()

#Making them integers (removing decimals)
CID_list = [int(i) for i in CID_list]

#Splitting CID_list into smaller strings (600 is around the max size for the full url)
list1 = CID_list[:600]
#switched from intervals of 600 to intervals of 500 (integers get larger)
list2 = CID_list[600:1100]
#switched from intervals of 500 to intervals of 600
list3 = CID_list[1100:1800]
list4 = CID_list[1800:2400]
list5 = CID_list[2400:3000]
list6 = CID_list[3000:3600]
list7 = CID_list[3600:4200]
list8 = CID_list[4200:4800]
list9 = CID_list[4800:5400]
list10 = CID_list[5400:5900]
list11 = CID_list[5900:6400]
#switched from intervals of 500 to intervals of 300 (integers get larger)
list12 = CID_list[6400:6700]
list13 = CID_list[6700:7000]
list14 = CID_list[7000:7300]
list15 = CID_list[7300:7600]
list16 = CID_list[7600:7900]
list17 = CID_list[7900:8200]
list18 = CID_list[8200:]

#Changing list to str, dropping start/end brackets, removing spaces
str1 = (str(list1)[1:-1])
str1 = str1.replace(' ', '')
str2 = (str(list2)[1:-1])
str2 = str2.replace(' ', '')
str3 = (str(list3)[1:-1])
str3 = str3.replace(' ', '')
str4 = (str(list4)[1:-1])
str4 = str4.replace(' ', '')
str5 = (str(list5)[1:-1])
str5 = str5.replace(' ', '')
str6 = (str(list6)[1:-1])
str6 = str6.replace(' ', '')
str7 = (str(list7)[1:-1])
str7 = str7.replace(' ', '')
str8 = (str(list8)[1:-1])
str8 = str8.replace(' ', '')
str9 = (str(list9)[1:-1])
str9 = str9.replace(' ', '')
str10 = (str(list10)[1:-1])
str10 = str10.replace(' ', '')
str11 = (str(list11)[1:-1])
str11 = str11.replace(' ', '')
str12 = (str(list12)[1:-1])
str12 = str12.replace(' ', '')
str13 = (str(list13)[1:-1])
str13 = str13.replace(' ', '')
str14 = (str(list14)[1:-1])
str14 = str14.replace(' ', '')
str15 = (str(list15)[1:-1])
str15 = str15.replace(' ', '')
str16 = (str(list16)[1:-1])
str16 = str16.replace(' ', '')
str17 = (str(list17)[1:-1])
str17 = str17.replace(' ', '')
str18 = (str(list18)[1:-1])
str18 = str18.replace(' ', '')

# %%
#opening and reading the 13 molecular formula URLs
url1 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str1 + '/property/MolecularFormula/TXT')
html1 = urlopen(url1) 
soup1 = BeautifulSoup(html1, 'lxml')
url2 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str2 + '/property/MolecularFormula/TXT')
html2 = urlopen(url2) 
soup2 = BeautifulSoup(html2, 'lxml')
url3 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str3 + '/property/MolecularFormula/TXT')
html3 = urlopen(url3) 
soup3 = BeautifulSoup(html3, 'lxml')
url4 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str4 + '/property/MolecularFormula/TXT')
html4 = urlopen(url4) 
soup4 = BeautifulSoup(html4, 'lxml')
url5 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str5 + '/property/MolecularFormula/TXT')
html5 = urlopen(url5) 
soup5 = BeautifulSoup(html5, 'lxml')
url6 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str6 + '/property/MolecularFormula/TXT')
html6 = urlopen(url6) 
soup6 = BeautifulSoup(html6, 'lxml')
url7 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str7 + '/property/MolecularFormula/TXT')
html7 = urlopen(url7) 
soup7 = BeautifulSoup(html7, 'lxml')
url8 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str8 + '/property/MolecularFormula/TXT')
html8 = urlopen(url8)
soup8 = BeautifulSoup(html8, 'lxml')

formulas1 = soup1.get_text()
formulas2 = soup2.get_text()
formulas3 = soup3.get_text()
formulas4 = soup4.get_text()
formulas5 = soup5.get_text()
formulas6 = soup6.get_text()
formulas7 = soup7.get_text()
formulas8 = soup8.get_text()

# %%
url9 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str9 + '/property/MolecularFormula/TXT')
html9 = urlopen(url9) 
soup9 = BeautifulSoup(html9, 'lxml')
url10 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str10 + '/property/MolecularFormula/TXT')
html10 = urlopen(url10) 
soup10 = BeautifulSoup(html10, 'lxml')
url11 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str11 + '/property/MolecularFormula/TXT')
html11 = urlopen(url11) 
soup11 = BeautifulSoup(html11, 'lxml')
url12 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str12 + '/property/MolecularFormula/TXT')
html12 = urlopen(url12) 
soup12 = BeautifulSoup(html12, 'lxml')

formulas9 = soup9.get_text()
formulas10 = soup10.get_text()
formulas11 = soup11.get_text()
formulas12 = soup12.get_text()

# %%
url13 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str13 + '/property/MolecularFormula/TXT')
html13 = urlopen(url13) 
soup13 = BeautifulSoup(html13, 'lxml')
url14 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str14 + '/property/MolecularFormula/TXT')
html14 = urlopen(url14) 
soup14 = BeautifulSoup(html14, 'lxml')
url15 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str15 + '/property/MolecularFormula/TXT')
html15 = urlopen(url15) 
soup15 = BeautifulSoup(html15, 'lxml')
url16 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str16 + '/property/MolecularFormula/TXT')
html16 = urlopen(url16) 
soup16 = BeautifulSoup(html16, 'lxml')
url17 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str17 + '/property/MolecularFormula/TXT')
html17 = urlopen(url17) 
soup17 = BeautifulSoup(html17, 'lxml')
url18 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str18 + '/property/MolecularFormula/TXT')
html18 = urlopen(url18) 
soup18 = BeautifulSoup(html18, 'lxml')

formulas13 = soup13.get_text()
formulas14 = soup14.get_text()
formulas15 = soup15.get_text()
formulas16 = soup16.get_text()
formulas17 = soup17.get_text()
formulas18 = soup18.get_text()

#total formulas string
formula = formulas1 + formulas2 + formulas3 + formulas4 + formulas5 + formulas6 + formulas7 + formulas8 + formulas9 + formulas10 + formulas11 + formulas12 + formulas13 + formulas14 + formulas15 + formulas16 + formulas17 + formulas18

#formulas string to formulas list
formula = formula.split()
#len(formula)

# %% [markdown]
# # Downloading Molecular Weights

# %%
#opening and reading the 13 molecular weight URLs
url1 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str1 + '/property/MolecularWeight/TXT')
html1 = urlopen(url1) 
soup1 = BeautifulSoup(html1, 'lxml')
url2 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str2 + '/property/MolecularWeight/TXT')
html2 = urlopen(url2) 
soup2 = BeautifulSoup(html2, 'lxml')
url3 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str3 + '/property/MolecularWeight/TXT')
html3 = urlopen(url3) 
soup3 = BeautifulSoup(html3, 'lxml')
url4 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str4 + '/property/MolecularWeight/TXT')
html4 = urlopen(url4) 
soup4 = BeautifulSoup(html4, 'lxml')
url5 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str5 + '/property/MolecularWeight/TXT')
html5 = urlopen(url5) 
soup5 = BeautifulSoup(html5, 'lxml')
url6 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str6 + '/property/MolecularWeight/TXT')
html6 = urlopen(url6) 
soup6 = BeautifulSoup(html6, 'lxml')
url7 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str7 + '/property/MolecularWeight/TXT')
html7 = urlopen(url7) 
soup7 = BeautifulSoup(html7, 'lxml')
url8 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str8 + '/property/MolecularWeight/TXT')
html8 = urlopen(url8)
soup8 = BeautifulSoup(html8, 'lxml')

weights1 = soup1.get_text()
weights2 = soup2.get_text()
weights3 = soup3.get_text()
weights4 = soup4.get_text()
weights5 = soup5.get_text()
weights6 = soup6.get_text()
weights7 = soup7.get_text()
weights8 = soup8.get_text()

# %%
url9 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str9 + '/property/MolecularWeight/TXT')
html9 = urlopen(url9) 
soup9 = BeautifulSoup(html9, 'lxml')
url10 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str10 + '/property/MolecularWeight/TXT')
html10 = urlopen(url10) 
soup10 = BeautifulSoup(html10, 'lxml')
url11 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str11 + '/property/MolecularWeight/TXT')
html11 = urlopen(url11) 
soup11 = BeautifulSoup(html11, 'lxml')
url12 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str12 + '/property/MolecularWeight/TXT')
html12 = urlopen(url12) 
soup12 = BeautifulSoup(html12, 'lxml')

weights9 = soup9.get_text()
weights10 = soup10.get_text()
weights11 = soup11.get_text()
weights12 = soup12.get_text()

# %%
url13 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str13 + '/property/MolecularWeight/TXT')
html13 = urlopen(url13) 
soup13 = BeautifulSoup(html13, 'lxml')
url14 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str14 + '/property/MolecularWeight/TXT')
html14 = urlopen(url14) 
soup14 = BeautifulSoup(html14, 'lxml')
url15 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str15 + '/property/MolecularWeight/TXT')
html15 = urlopen(url15) 
soup15 = BeautifulSoup(html15, 'lxml')
url16 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str16 + '/property/MolecularWeight/TXT')
html16 = urlopen(url16) 
soup16 = BeautifulSoup(html16, 'lxml')
url17 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str17 + '/property/MolecularFormula/TXT')
html17 = urlopen(url17) 
soup17 = BeautifulSoup(html17, 'lxml')
url18 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str18 + '/property/MolecularFormula/TXT')
html18 = urlopen(url18) 
soup18 = BeautifulSoup(html18, 'lxml')

weights13 = soup13.get_text()
weights14 = soup14.get_text()
weights15 = soup15.get_text()
weights16 = soup16.get_text()
weights17 = soup17.get_text()
weights18 = soup18.get_text()

#total weights string
weights = weights1 + weights2 + weights3 + weights4 + weights5 + weights6 + weights7 + weights8 + weights9 + weights10 + weights11 + weights12 + weights13 + weights14 + weights15 + weights16 + weights17 + weights18

#weight string to weight list
weights = weights.split()
#len(weights)
# Out:
# 8684

# %% [markdown]
# # Downloading Canonical Smiles

# %%
#opening and reading the 13 canonical SMILES URLs
url1 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str1 + '/property/CanonicalSMILES/TXT')
html1 = urlopen(url1) 
soup1 = BeautifulSoup(html1, 'lxml')
url2 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str2 + '/property/CanonicalSMILES/TXT')
html2 = urlopen(url2) 
soup2 = BeautifulSoup(html2, 'lxml')
url3 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str3 + '/property/CanonicalSMILES/TXT')
html3 = urlopen(url3) 
soup3 = BeautifulSoup(html3, 'lxml')
url4 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str4 + '/property/CanonicalSMILES/TXT')
html4 = urlopen(url4) 
soup4 = BeautifulSoup(html4, 'lxml')
url5 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str5 + '/property/CanonicalSMILES/TXT')
html5 = urlopen(url5) 
soup5 = BeautifulSoup(html5, 'lxml')
url6 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str6 + '/property/CanonicalSMILES/TXT')
html6 = urlopen(url6) 
soup6 = BeautifulSoup(html6, 'lxml')
url7 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str7 + '/property/CanonicalSMILES/TXT')
html7 = urlopen(url7) 
soup7 = BeautifulSoup(html7, 'lxml')
url8 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str8 + '/property/CanonicalSMILES/TXT')
html8 = urlopen(url8)
soup8 = BeautifulSoup(html8, 'lxml')

cSMILES1 = soup1.get_text()
cSMILES2 = soup2.get_text()
cSMILES3 = soup3.get_text()
cSMILES4 = soup4.get_text()
cSMILES5 = soup5.get_text()
cSMILES6 = soup6.get_text()
cSMILES7 = soup7.get_text()
cSMILES8 = soup8.get_text()

# %%
url9 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str9 + '/property/CanonicalSMILES/TXT')
html9 = urlopen(url9) 
soup9 = BeautifulSoup(html9, 'lxml')
url10 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str10 + '/property/CanonicalSMILES/TXT')
html10 = urlopen(url10) 
soup10 = BeautifulSoup(html10, 'lxml')
url11 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str11 + '/property/CanonicalSMILES/TXT')
html11 = urlopen(url11) 
soup11 = BeautifulSoup(html11, 'lxml')
url12 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str12 + '/property/CanonicalSMILES/TXT')
html12 = urlopen(url12) 
soup12 = BeautifulSoup(html12, 'lxml')

cSMILES9 = soup9.get_text()
cSMILES10 = soup10.get_text()
cSMILES11 = soup11.get_text()
cSMILES12 = soup12.get_text()

# %%
url13 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str13 + '/property/CanonicalSMILES/TXT')
html13 = urlopen(url13) 
soup13 = BeautifulSoup(html13, 'lxml')
url14 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str14 + '/property/CanonicalSMILES/TXT')
html14 = urlopen(url14) 
soup14 = BeautifulSoup(html14, 'lxml')
url15 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str15 + '/property/CanonicalSMILES/TXT')
html15 = urlopen(url15) 
soup15 = BeautifulSoup(html15, 'lxml')
url16 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str16 + '/property/CanonicalSMILES/TXT')
html16 = urlopen(url16) 
soup16 = BeautifulSoup(html16, 'lxml')
url17 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str17 + '/property/MolecularFormula/TXT')
html17 = urlopen(url17) 
soup17 = BeautifulSoup(html17, 'lxml')
url18 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str18 + '/property/MolecularFormula/TXT')
html18 = urlopen(url18) 
soup18 = BeautifulSoup(html18, 'lxml')

cSMILES13 = soup13.get_text()
cSMILES14 = soup14.get_text()
cSMILES15 = soup15.get_text()
cSMILES16 = soup16.get_text()
cSMILES17 = soup17.get_text()
cSMILES18 = soup18.get_text()

#total cSMILES string
cSMILES = cSMILES1 + cSMILES2 + cSMILES3 + cSMILES4 + cSMILES5 + cSMILES6 + cSMILES7 + cSMILES8 + cSMILES9 + cSMILES10 + cSMILES11 + cSMILES12 + cSMILES13 + cSMILES14 + cSMILES15 + cSMILES16 + cSMILES17 + cSMILES18

#weight string to cSMILES list
cSMILES = cSMILES.split()
#len(cSMILES)

# %% [markdown]
# # Downloading Isomeric Smiles

# %%
#opening and reading the 13 canonical SMILES URLs
url1 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str1 + '/property/IsomericSMILES/TXT')
html1 = urlopen(url1) 
soup1 = BeautifulSoup(html1, 'lxml')
url2 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str2 + '/property/IsomericSMILES/TXT')
html2 = urlopen(url2) 
soup2 = BeautifulSoup(html2, 'lxml')
url3 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str3 + '/property/IsomericSMILES/TXT')
html3 = urlopen(url3) 
soup3 = BeautifulSoup(html3, 'lxml')
url4 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str4 + '/property/IsomericSMILES/TXT')
html4 = urlopen(url4) 
soup4 = BeautifulSoup(html4, 'lxml')
url5 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str5 + '/property/IsomericSMILES/TXT')
html5 = urlopen(url5) 
soup5 = BeautifulSoup(html5, 'lxml')
url6 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str6 + '/property/IsomericSMILES/TXT')
html6 = urlopen(url6) 
soup6 = BeautifulSoup(html6, 'lxml')
url7 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str7 + '/property/IsomericSMILES/TXT')
html7 = urlopen(url7) 
soup7 = BeautifulSoup(html7, 'lxml')
url8 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str8 + '/property/IsomericSMILES/TXT')
html8 = urlopen(url8)
soup8 = BeautifulSoup(html8, 'lxml')

iSMILES1 = soup1.get_text()
iSMILES2 = soup2.get_text()
iSMILES3 = soup3.get_text()
iSMILES4 = soup4.get_text()
iSMILES5 = soup5.get_text()
iSMILES6 = soup6.get_text()
iSMILES7 = soup7.get_text()
iSMILES8 = soup8.get_text()

# %%
url9 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str9 + '/property/IsomericSMILES/TXT')
html9 = urlopen(url9) 
soup9 = BeautifulSoup(html9, 'lxml')
url10 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str10 + '/property/IsomericSMILES/TXT')
html10 = urlopen(url10) 
soup10 = BeautifulSoup(html10, 'lxml')
url11 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str11 + '/property/IsomericSMILES/TXT')
html11 = urlopen(url11) 
soup11 = BeautifulSoup(html11, 'lxml')
url12 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str12 + '/property/IsomericSMILES/TXT')
html12 = urlopen(url12) 
soup12 = BeautifulSoup(html12, 'lxml')

iSMILES9 = soup9.get_text()
iSMILES10 = soup10.get_text()
iSMILES11 = soup11.get_text()
iSMILES12 = soup12.get_text()

# %%
url13 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str13 + '/property/IsomericSMILES/TXT')
html13 = urlopen(url13) 
soup13 = BeautifulSoup(html13, 'lxml')
url14 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str14 + '/property/IsomericSMILES/TXT')
html14 = urlopen(url14) 
soup14 = BeautifulSoup(html14, 'lxml')
url15 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str15 + '/property/IsomericSMILES/TXT')
html15 = urlopen(url15) 
soup15 = BeautifulSoup(html15, 'lxml')
url16 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str16 + '/property/IsomericSMILES/TXT')
html16 = urlopen(url16) 
soup16 = BeautifulSoup(html16, 'lxml')
url17 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str17 + '/property/MolecularFormula/TXT')
html17 = urlopen(url17) 
soup17 = BeautifulSoup(html17, 'lxml')
url18 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str18 + '/property/MolecularFormula/TXT')
html18 = urlopen(url18) 
soup18 = BeautifulSoup(html18, 'lxml')

iSMILES13 = soup13.get_text()
iSMILES14 = soup14.get_text()
iSMILES15 = soup15.get_text()
iSMILES16 = soup16.get_text()
iSMILES17 = soup17.get_text()
iSMILES18 = soup18.get_text()

#total iSMILES string
iSMILES = iSMILES1 + iSMILES2 + iSMILES3 + iSMILES4 + iSMILES5 + iSMILES6 + iSMILES7 + iSMILES8 + iSMILES9 + iSMILES10 + iSMILES11 + iSMILES12 + iSMILES13 + iSMILES14 + iSMILES15 + iSMILES16 + iSMILES17 + iSMILES18

#weight string to iSMILES list
iSMILES = iSMILES.split()
#len(iSMILES)

# %% [markdown]
# # Downloading InChI (international chemical identifier)

# %%
#opening and reading the 13 international chemical identifier (InChI) URLs
url1 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str1 + '/property/InChI/TXT')
html1 = urlopen(url1) 
soup1 = BeautifulSoup(html1, 'lxml')
url2 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str2 + '/property/InChI/TXT')
html2 = urlopen(url2) 
soup2 = BeautifulSoup(html2, 'lxml')
url3 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str3 + '/property/InChI/TXT')
html3 = urlopen(url3) 
soup3 = BeautifulSoup(html3, 'lxml')
url4 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str4 + '/property/InChI/TXT')
html4 = urlopen(url4) 
soup4 = BeautifulSoup(html4, 'lxml')
url5 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str5 + '/property/InChI/TXT')
html5 = urlopen(url5) 
soup5 = BeautifulSoup(html5, 'lxml')
url6 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str6 + '/property/InChI/TXT')
html6 = urlopen(url6) 
soup6 = BeautifulSoup(html6, 'lxml')
url7 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str7 + '/property/InChI/TXT')
html7 = urlopen(url7) 
soup7 = BeautifulSoup(html7, 'lxml')
url8 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str8 + '/property/InChI/TXT')
html8 = urlopen(url8)
soup8 = BeautifulSoup(html8, 'lxml')

InChI1 = soup1.get_text()
InChI2 = soup2.get_text()
InChI3 = soup3.get_text()
InChI4 = soup4.get_text()
InChI5 = soup5.get_text()
InChI6 = soup6.get_text()
InChI7 = soup7.get_text()
InChI8 = soup8.get_text()

# %%
url9 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str9 + '/property/InChI/TXT')
html9 = urlopen(url9) 
soup9 = BeautifulSoup(html9, 'lxml')
url10 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str10 + '/property/InChI/TXT')
html10 = urlopen(url10) 
soup10 = BeautifulSoup(html10, 'lxml')
url11 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str11 + '/property/InChI/TXT')
html11 = urlopen(url11) 
soup11 = BeautifulSoup(html11, 'lxml')
url12 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str12 + '/property/InChI/TXT')
html12 = urlopen(url12) 
soup12 = BeautifulSoup(html12, 'lxml')

InChI9 = soup9.get_text()
InChI10 = soup10.get_text()
InChI11 = soup11.get_text()
InChI12 = soup12.get_text()

# %%
url13 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str13 + '/property/InChI/TXT')
html13 = urlopen(url13) 
soup13 = BeautifulSoup(html13, 'lxml')
url14 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str14 + '/property/InChI/TXT')
html14 = urlopen(url14) 
soup14 = BeautifulSoup(html14, 'lxml')
url15 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str15 + '/property/InChI/TXT')
html15 = urlopen(url15) 
soup15 = BeautifulSoup(html15, 'lxml')
url16 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str16 + '/property/InChI/TXT')
html16 = urlopen(url16) 
soup16 = BeautifulSoup(html16, 'lxml')
url17 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str17 + '/property/MolecularFormula/TXT')
html17 = urlopen(url17) 
soup17 = BeautifulSoup(html17, 'lxml')
url18 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str18 + '/property/MolecularFormula/TXT')
html18 = urlopen(url18) 
soup18 = BeautifulSoup(html18, 'lxml')

InChI13 = soup13.get_text()
InChI14 = soup14.get_text()
InChI15 = soup15.get_text()
InChI16 = soup16.get_text()
InChI17 = soup17.get_text()
InChI18 = soup18.get_text()

#total InChI string
InChI = InChI1 + InChI2 + InChI3 + InChI4 + InChI5 + InChI6 + InChI7 + InChI8 + InChI9 + InChI10 + InChI11 + InChI12 + InChI13 + InChI14 + InChI15 + InChI16 + InChI17 + InChI18

#weight string to InChI list
InChI = InChI.split()
#len(InChI)

# %% [markdown]
# # Downloading XLogP NOT DONE

# %%
#Getting list of XLogP values for all CID
#We do this because some values don't have XLogP values
#takes like an hr to run

XLogP = []
i = 0
while i < len(CID_list):
    try:
    # (list_cov_multi[i] == '2'):
        url1 = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str(CID_list[i]) + '/property/XLogP/TXT'
        html1 = urlopen(url1) 
        soup1 = BeautifulSoup(html1, 'lxml')
        parent1 = soup1.get_text()
        XLogP.append(parent1)
        i = i + 1
       # else:
        #    i = i + 1
    except:
       
        XLogP.append('None')
        i = i + 1

len(XLogP)

# %%
#opening and reading the 13 international chemical identifier (XLogP) URLs
url1 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str1 + '/property/XLogP/TXT')
html1 = urlopen(url1) 
soup1 = BeautifulSoup(html1, 'lxml')
url2 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str2 + '/property/XLogP/TXT')
html2 = urlopen(url2) 
soup2 = BeautifulSoup(html2, 'lxml')
url3 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str3 + '/property/XLogP/TXT')
html3 = urlopen(url3) 
soup3 = BeautifulSoup(html3, 'lxml')
url4 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str4 + '/property/XLogP/TXT')
html4 = urlopen(url4) 
soup4 = BeautifulSoup(html4, 'lxml')
url5 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str5 + '/property/XLogP/TXT')
html5 = urlopen(url5) 
soup5 = BeautifulSoup(html5, 'lxml')
url6 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str6 + '/property/XLogP/TXT')
html6 = urlopen(url6) 
soup6 = BeautifulSoup(html6, 'lxml')
url7 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str7 + '/property/XLogP/TXT')
html7 = urlopen(url7) 
soup7 = BeautifulSoup(html7, 'lxml')
url8 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str8 + '/property/XLogP/TXT')
html8 = urlopen(url8)
soup8 = BeautifulSoup(html8, 'lxml')

XLogP1 = soup1.get_text()
XLogP2 = soup2.get_text()
XLogP3 = soup3.get_text()
XLogP4 = soup4.get_text()
XLogP5 = soup5.get_text()
XLogP6 = soup6.get_text()
XLogP7 = soup7.get_text()
XLogP8 = soup8.get_text()

# %%
url9 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str9 + '/property/XLogP/TXT')
html9 = urlopen(url9) 
soup9 = BeautifulSoup(html9, 'lxml')
url10 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str10 + '/property/XLogP/TXT')
html10 = urlopen(url10) 
soup10 = BeautifulSoup(html10, 'lxml')
url11 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str11 + '/property/XLogP/TXT')
html11 = urlopen(url11) 
soup11 = BeautifulSoup(html11, 'lxml')
url12 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str12 + '/property/XLogP/TXT')
html12 = urlopen(url12) 
soup12 = BeautifulSoup(html12, 'lxml')

XLogP9 = soup9.get_text()
XLogP10 = soup10.get_text()
XLogP11 = soup11.get_text()
XLogP12 = soup12.get_text()

# %%
url13 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str13 + '/property/XLogP/TXT')
html13 = urlopen(url13) 
soup13 = BeautifulSoup(html13, 'lxml')
url14 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str14 + '/property/XLogP/TXT')
html14 = urlopen(url14) 
soup14 = BeautifulSoup(html14, 'lxml')
url15 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str15 + '/property/XLogP/TXT')
html15 = urlopen(url15) 
soup15 = BeautifulSoup(html15, 'lxml')
url16 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str16 + '/property/XLogP/TXT')
html16 = urlopen(url16) 
soup16 = BeautifulSoup(html16, 'lxml')
url17 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str17 + '/property/MolecularFormula/TXT')
html17 = urlopen(url17) 
soup17 = BeautifulSoup(html17, 'lxml')
url18 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str18 + '/property/MolecularFormula/TXT')
html18 = urlopen(url18) 
soup18 = BeautifulSoup(html18, 'lxml')

XLogP13 = soup13.get_text()
XLogP14 = soup14.get_text()
XLogP15 = soup15.get_text()
XLogP16 = soup16.get_text()
XLogP17 = soup17.get_text()
XLogP18 = soup18.get_text()

#total XLogP string
XLogP = XLogP1 + XLogP2 + XLogP3 + XLogP4 + XLogP5 + XLogP6 + XLogP7 + XLogP8 + XLogP9 + XLogP10 + XLogP11 + XLogP12 + XLogP13 + XLogP14 + XLogP15 + XLogP16 + XLogP17 + XLogP18

#weight string to XLogP list
XLogP = XLogP.split()
len(XLogP)
# Out:
# 7193

# %% [markdown]
# # Downloading Exact Mass

# %%
#opening and reading the 13 Exact Mass URLs
url1 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str1 + '/property/ExactMass/TXT')
html1 = urlopen(url1) 
soup1 = BeautifulSoup(html1, 'lxml')
url2 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str2 + '/property/ExactMass/TXT')
html2 = urlopen(url2) 
soup2 = BeautifulSoup(html2, 'lxml')
url3 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str3 + '/property/ExactMass/TXT')
html3 = urlopen(url3) 
soup3 = BeautifulSoup(html3, 'lxml')
url4 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str4 + '/property/ExactMass/TXT')
html4 = urlopen(url4) 
soup4 = BeautifulSoup(html4, 'lxml')
url5 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str5 + '/property/ExactMass/TXT')
html5 = urlopen(url5) 
soup5 = BeautifulSoup(html5, 'lxml')
url6 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str6 + '/property/ExactMass/TXT')
html6 = urlopen(url6) 
soup6 = BeautifulSoup(html6, 'lxml')
url7 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str7 + '/property/ExactMass/TXT')
html7 = urlopen(url7) 
soup7 = BeautifulSoup(html7, 'lxml')
url8 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str8 + '/property/ExactMass/TXT')
html8 = urlopen(url8)
soup8 = BeautifulSoup(html8, 'lxml')

eMass1 = soup1.get_text()
eMass2 = soup2.get_text()
eMass3 = soup3.get_text()
eMass4 = soup4.get_text()
eMass5 = soup5.get_text()
eMass6 = soup6.get_text()
eMass7 = soup7.get_text()
eMass8 = soup8.get_text()

# %%
url9 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str9 + '/property/ExactMass/TXT')
html9 = urlopen(url9) 
soup9 = BeautifulSoup(html9, 'lxml')
url10 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str10 + '/property/ExactMass/TXT')
html10 = urlopen(url10) 
soup10 = BeautifulSoup(html10, 'lxml')
url11 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str11 + '/property/ExactMass/TXT')
html11 = urlopen(url11) 
soup11 = BeautifulSoup(html11, 'lxml')
url12 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str12 + '/property/ExactMass/TXT')
html12 = urlopen(url12) 
soup12 = BeautifulSoup(html12, 'lxml')

eMass9 = soup9.get_text()
eMass10 = soup10.get_text()
eMass11 = soup11.get_text()
eMass12 = soup12.get_text()

# %%
url13 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str13 + '/property/ExactMass/TXT')
html13 = urlopen(url13) 
soup13 = BeautifulSoup(html13, 'lxml')
url14 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str14 + '/property/ExactMass/TXT')
html14 = urlopen(url14) 
soup14 = BeautifulSoup(html14, 'lxml')
url15 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str15 + '/property/ExactMass/TXT')
html15 = urlopen(url15) 
soup15 = BeautifulSoup(html15, 'lxml')
url16 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str16 + '/property/ExactMass/TXT')
html16 = urlopen(url16) 
soup16 = BeautifulSoup(html16, 'lxml')
url17 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str17 + '/property/MolecularFormula/TXT')
html17 = urlopen(url17) 
soup17 = BeautifulSoup(html17, 'lxml')
url18 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str18 + '/property/MolecularFormula/TXT')
html18 = urlopen(url18) 
soup18 = BeautifulSoup(html18, 'lxml')

eMass13 = soup13.get_text()
eMass14 = soup14.get_text()
eMass15 = soup15.get_text()
eMass16 = soup16.get_text()
eMass17 = soup17.get_text()
eMass18 = soup18.get_text()

#total eMass string
eMass = eMass1 + eMass2 + eMass3 + eMass4 + eMass5 + eMass6 + eMass7 + eMass8 + eMass9 + eMass10 + eMass11 + eMass12 + eMass13 + eMass14 + eMass15 + eMass16 + eMass17 + eMass18

#weight string to eMass list
eMass = eMass.split()
#len(eMass)

# %% [markdown]
# # Downloading Topological Polar Surface Area (TPSA)

# %%
#opening and reading the 13 Topological Polar Surface Area (TPSA) URLs
url1 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str1 + '/property/TPSA/TXT')
html1 = urlopen(url1) 
soup1 = BeautifulSoup(html1, 'lxml')
url2 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str2 + '/property/TPSA/TXT')
html2 = urlopen(url2) 
soup2 = BeautifulSoup(html2, 'lxml')
url3 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str3 + '/property/TPSA/TXT')
html3 = urlopen(url3) 
soup3 = BeautifulSoup(html3, 'lxml')
url4 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str4 + '/property/TPSA/TXT')
html4 = urlopen(url4) 
soup4 = BeautifulSoup(html4, 'lxml')
url5 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str5 + '/property/TPSA/TXT')
html5 = urlopen(url5) 
soup5 = BeautifulSoup(html5, 'lxml')
url6 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str6 + '/property/TPSA/TXT')
html6 = urlopen(url6) 
soup6 = BeautifulSoup(html6, 'lxml')
url7 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str7 + '/property/TPSA/TXT')
html7 = urlopen(url7) 
soup7 = BeautifulSoup(html7, 'lxml')
url8 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str8 + '/property/TPSA/TXT')
html8 = urlopen(url8)
soup8 = BeautifulSoup(html8, 'lxml')

TPSA1 = soup1.get_text()
TPSA2 = soup2.get_text()
TPSA3 = soup3.get_text()
TPSA4 = soup4.get_text()
TPSA5 = soup5.get_text()
TPSA6 = soup6.get_text()
TPSA7 = soup7.get_text()
TPSA8 = soup8.get_text()

# %%
url9 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str9 + '/property/TPSA/TXT')
html9 = urlopen(url9) 
soup9 = BeautifulSoup(html9, 'lxml')
url10 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str10 + '/property/TPSA/TXT')
html10 = urlopen(url10) 
soup10 = BeautifulSoup(html10, 'lxml')
url11 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str11 + '/property/TPSA/TXT')
html11 = urlopen(url11) 
soup11 = BeautifulSoup(html11, 'lxml')
url12 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str12 + '/property/TPSA/TXT')
html12 = urlopen(url12) 
soup12 = BeautifulSoup(html12, 'lxml')

TPSA9 = soup9.get_text()
TPSA10 = soup10.get_text()
TPSA11 = soup11.get_text()
TPSA12 = soup12.get_text()

# %%
url13 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str13 + '/property/TPSA/TXT')
html13 = urlopen(url13) 
soup13 = BeautifulSoup(html13, 'lxml')
url14 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str14 + '/property/TPSA/TXT')
html14 = urlopen(url14) 
soup14 = BeautifulSoup(html14, 'lxml')
url15 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str15 + '/property/TPSA/TXT')
html15 = urlopen(url15) 
soup15 = BeautifulSoup(html15, 'lxml')
url16 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str16 + '/property/TPSA/TXT')
html16 = urlopen(url16) 
soup16 = BeautifulSoup(html16, 'lxml')
url17 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str17 + '/property/MolecularFormula/TXT')
html17 = urlopen(url17) 
soup17 = BeautifulSoup(html17, 'lxml')
url18 = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str18 + '/property/MolecularFormula/TXT')
html18 = urlopen(url18) 
soup18 = BeautifulSoup(html18, 'lxml')

TPSA13 = soup13.get_text()
TPSA14 = soup14.get_text()
TPSA15 = soup15.get_text()
TPSA16 = soup16.get_text()
TPSA17 = soup17.get_text()
TPSA18 = soup18.get_text()

#total TPSA string
TPSA = TPSA1 + TPSA2 + TPSA3 + TPSA4 + TPSA5 + TPSA6 + TPSA7 + TPSA8 + TPSA9 + TPSA10 + TPSA11 + TPSA12 + TPSA13 + TPSA14 + TPSA15 + TPSA16 + TPSA17 + TPSA18

#weight string to TPSA list
TPSA = TPSA.split()
#len(TPSA)

# %% [markdown]
# # Adding molecular properties into DF

# %%
#Making a copy of the original data dataframe
df_full = data
df_full['MolecularFormula'] = formula
df_full['MolecularWeight'] = weights
df_full['CanonicalSMILES'] = cSMILES
df_full['IsomericSMILES'] = iSMILES
df_full['InChI'] = InChI
#df_full['XLogP'] = XLogP
df_full['ExactMass'] = eMass
df_full['TPSA'] = TPSA
df_full
# Out:
#        Activity Summary  PUBCHEM_CID  Ratio Efficacy (%)  Ratio Potency (uM)  \
# 0              inactive          997              0.0000            0.000000
# 1     active antagonist         1807           -116.2980           54.941000
# 2     active antagonist         2453           -141.2610           10.682200
# 3     active antagonist         2662            -42.8802           21.313800
# 4     active antagonist         2722           -116.0110            5.563230
# 5              inactive         2726              0.0000            0.000000
# 6     active antagonist         2812           -123.0110            6.441820
# 7     active antagonist         3080            -69.4724           20.511300
# 8              inactive         3295              0.0000            0.000000
# 9     active antagonist         3371            -89.3002           43.641200
# 10             inactive         3589              0.0000            0.000000
# ...

# %%
df_full.iloc[2767]
# Out:
# PUBCHEM_CID                                                        8295
# Activity Summary                                               inactive
# Ratio Potency (uM)                                                    0
# Ratio Efficacy (%)                                                    0
# MolecularFormula                                            C6H12Cl3O4P
# MolecularWeight                                              285.482000
# CanonicalSMILES                                C(CCl)OP(=O)(OCCCl)OCCCl
# IsomericSMILES                                 C(CCl)OP(=O)(OCCCl)OCCCl
# InChI                 InChI=1S/C6H12Cl3O4P/c7-1-4-11-14(10,12-5-2-8)...
# ExactMass                                                    283.954000
# TPSA                                                               44.8
# Name: 2767, dtype: object

# %%
df_full.iloc[6113]
# Out:
# PUBCHEM_CID                                                 3.74466e+06
# Activity Summary                                               inactive
# Ratio Potency (uM)                                                    0
# Ratio Efficacy (%)                                                    0
# MolecularFormula                                           C18H46N2O8Ti
# MolecularWeight                                              466.439000
# CanonicalSMILES        CC(C)O.CC(C)O.C(CO)N(CCO)CCO.C(CO)N(CCO)CCO.[Ti]
# IsomericSMILES         CC(C)O.CC(C)O.C(CO)N(CCO)CCO.C(CO)N(CCO)CCO.[Ti]
# InChI                 InChI=1S/2C6H15NO3.2C3H8O.Ti/c2*8-4-1-7(2-5-9)...
# ExactMass                                                    466.273000
# TPSA                                                              168.0
# Name: 6113, dtype: object

# %%
#Writing to csv
df_full.to_csv('Molecular_Properties_CSV', index = False)
final = pd.read_csv('Molecular_Properties_CSV')
#final.head()

# %%
#URL for covalent count
https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/3080/property/CovalentUnitCount/TXT
