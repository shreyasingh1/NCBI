# %%
#importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#hiding warning messages
import warnings
warnings.filterwarnings("ignore")

#Reading in Summary ANTAGONIST CSV
data = pd.read_csv('CleanedAntagonistData.csv')
data = data.iloc[0:]
data = data.reset_index()
data.head(5)
#data.dtypes
# Out:
#    index  PUBCHEM_SID  PUBCHEM_CID  PUBCHEM_ACTIVITY_SCORE            \
# 0      0    144212021            4                       0  inactive
# 1      1    144209664           11                       0  inactive
# 2      2    144210880           13                       0  inactive
# 3      3    144211469           33                       0  inactive
# 4      4    144210363           34                       0  inactive
#
#   Ratio Activity  Ratio Potency (uM)  Ratio Efficacy (%)
# 0       inactive                 NaN                 0.0
# 1       inactive                 NaN                 0.0
# 2       inactive                 NaN                 0.0
# 3       inactive                 NaN                 0.0
# 4       inactive                 NaN                 0.0

# %%
#Finding SID Duplicates
data_dupsSID = data.pivot_table(index=['PUBCHEM_SID'], aggfunc='size')

# %%
#Dictionary of SID || CID pairs, SID are keys
SID_CID_df = data[['PUBCHEM_CID', 'PUBCHEM_SID']]
SID_CID_df = SID_CID_df.set_index('PUBCHEM_CID')
SID_CID_dict = SID_CID_df.to_dict('index')

# %%
SID_CID_dict
# Out:
# {144203552.0: {'PUBCHEM_CID': 12850184.0},
#  144203553.0: {'PUBCHEM_CID': 89753.0},
#  144203554.0: {'PUBCHEM_CID': 9403.0},
#  144203555.0: {'PUBCHEM_CID': 13218779.0},
#  144203556.0: {'PUBCHEM_CID': 142766.0},
#  144203557.0: {'PUBCHEM_CID': 16043.0},
#  144203558.0: {'PUBCHEM_CID': 16043.0},
#  144203559.0: {'PUBCHEM_CID': 2724411.0},
#  144203560.0: {'PUBCHEM_CID': 2724372.0},
#  144203561.0: {'PUBCHEM_CID': 637566.0},
#  144203562.0: {'PUBCHEM_CID': 994.0},
#  144203563.0: {'PUBCHEM_CID': 4766.0},
#  144203564.0: {'PUBCHEM_CID': 79472.0},
#  144203565.0: {'PUBCHEM_CID': 3080.0},
#  144203566.0: {'PUBCHEM_CID': 197883.0},
#  144203567.0: {'PUBCHEM_CID': 51.0},
#  144203568.0: {'PUBCHEM_CID': 66064.0},
#  144203569.0: {'PUBCHEM_CID': 66435.0},
#  144203570.0: {'PUBCHEM_CID': 8969.0},
#  144203571.0: {'PUBCHEM_CID': 10664.0},
#  144203572.0: {'PUBCHEM_CID': 8739.0},
#  144203573.0: {'PUBCHEM_CID': 4904.0},
#  144203574.0: {'PUBCHEM_CID': 65463.0},
# ...
