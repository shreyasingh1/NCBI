# %% [markdown]
# # ***RUN NOTEBOOK IN ORDER

# %% [markdown]
# # Dealing with multicomponent compounds

# %% [markdown]
# # Data Cleaning Full (antag)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from requests import exceptions
import re
# %matplotlib inline

import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup

#hiding warning messages
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Read the antagonist assay data into a data frame

# %%
#Reading in Summary ANTAGONIST CSV
antag_pre = pd.read_csv('AID_588533_datatable_all.csv')
antag_pre = antag_pre.iloc[5:]
antag_pre.shape
# Out:
# (2858, 114)

# %%
antag_pre = antag_pre[['PUBCHEM_CID', 'PUBCHEM_ACTIVITY_OUTCOME']]
antag_pre.tail(3)
# Out:
#       PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME
# 2860      10788.0                 Inactive
# 2861      12901.0                 Inactive
# 2862       6872.0             Inconclusive

# %% [markdown]
# Deal with the NULL values: remove the rows without CIDs.

# %%
antag_pre.isnull().sum()
# Out:
# PUBCHEM_CID                 14
# PUBCHEM_ACTIVITY_OUTCOME     0
# dtype: int64

# %%
antag_pre = antag_pre[ antag_pre['PUBCHEM_CID'].notnull() ]
antag_pre.shape
# Out:
# (2844, 2)

# %% [markdown]
# Convert the PUBCHEM_CID (floats) into an integer type.

# %%
antag_pre['PUBCHEM_CID'] = antag_pre['PUBCHEM_CID'].astype(int)
antag_pre = antag_pre.rename(columns = {'PUBCHEM_ACTIVITY_OUTCOME' : 'Activity Summary'})
antag_pre.head(3)
# Out:
#    PUBCHEM_CID Activity Summary
# 5         5995           Active
# 6        26041     Inconclusive
# 7      5281576     Inconclusive

# %%
antag_pre['Activity Summary'].value_counts()
# Out:
# Inactive        2066
# Inconclusive     712
# Active            66
# Name: Activity Summary, dtype: int64

# %%
antag_pre.shape
# Out:
# (2844, 2)

# %%
antag_pre.head(3)
# Out:
#    PUBCHEM_CID Activity Summary
# 5         5995           Active
# 6        26041     Inconclusive
# 7      5281576     Inconclusive

# %% [markdown]
# # Identifying Covalent Unit Count (antag)

# %% [markdown]
# Compute the number of CID chunks based on the number of CIDs and the chunk size.

# %%
chunk_size = 200
num_cids = len(antag_pre['PUBCHEM_CID'])

if num_cids % chunk_size == 0 :
    num_chunks = int( num_cids / chunk_size )
else :
    num_chunks = int( num_cids / chunk_size ) + 1

print("# CIDs = ", num_cids)
print("# CID Chunks = ", num_chunks, "(chunked by ", chunk_size, ")")
# Out:
# # CIDs =  2844
# # CID Chunks =  15 (chunked by  200 )

# %% [markdown]
# Retrieve the covalent unit counts for each chunk of CIDs.

# %%
import time

frames = []  # temporary list to store data frames from each PUG-REST request.

#print("chunkid", 'idx1', 'idx2', 'length', sep="\t")

for i in range(0, num_chunks) :
    
    idx1 = chunk_size * i
    idx2 = chunk_size * (i + 1)
    cidstr = ",".join(antag_pre.PUBCHEM_CID[idx1:idx2].astype(str).tolist())

    url = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + cidstr + '/property/CovalentUnitCount/TXT')
    data = pd.read_csv( urllib.request.urlopen(url), header=None, names=['cov_units'] )
    frames.append(data)
    
    # Uncomment this line to check the progress
    #print(i, idx1, idx2, len(data), sep="\t")
    
    if (i % 5 == 0 ) :
        time.sleep(1)  # To comply with the PubChem usage polocy (no more than 5 requests per sec)

#    if ( i == 2 ) : break  #- for debugging

cov_units = pd.concat(frames,ignore_index=True)
print(cov_units.shape)
# Out:
# (2844, 1)

# %% [markdown]
# # Dealing with multicomponent molecules (antag)

# %%
antag_pre['CovalentUnitCount'] = cov_units.cov_units.tolist()
antag_pre.CovalentUnitCount.isnull().sum()
# Out:
# 0

# %%
antag_pre['CovalentUnitCount'].value_counts()
# Out:
# 1     2616
# 2      159
# 3       41
# 5       16
# 4        5
# 9        3
# 6        3
# 10       1
# Name: CovalentUnitCount, dtype: int64

# %%
cid_multicompo = antag_pre[ antag_pre.CovalentUnitCount > 1 ].PUBCHEM_CID.tolist()
len(cid_multicompo)
# Out:
# 228

# %% [markdown]
# The multicomponent CID list has some duplicate CIDs.  Removing them will reduce the number of PUG-REST requests later.

# %%
cid_multicompo.sort()
 
cid_multicompo_uniq = sorted( set(cid_multicompo) )
cid_multicompo_dup = []
    
for mycid in cid_multicompo_uniq:
        if ( cid_multicompo.count( mycid ) > 1 ):
            cid_multicompo_dup.append( mycid )

print(len(cid_multicompo_dup))
print(cid_multicompo_dup)

cid_multicompo = cid_multicompo_uniq
# Out:
# 31
# [5807, 5963, 8478, 8691, 8722, 8813, 11057, 11065, 11933, 13266, 15106, 22420, 22456, 23392, 62882, 108005, 443939, 2733525, 3032581, 3423265, 5284441, 5284484, 11074431, 11972286, 23668193, 23668195, 23668198, 23675274, 23678874, 44134384, 54680782]

# %% [markdown]
# Because downloading parent compound information through PUG-REST takes a long time, we want to store the data in a file when they are downloaded for later use. When the cell is run next time, it will read the data from the file, rather than downloading them from PubChem.

# %%
import os.path
import json

cid_parent= {}
file_parent = 'cid_parent.json'

if os.path.isfile(file_parent) and os.path.getsize(file_parent) :
    
    with open('cid_parent.json') as f:
        cid_parent = json.load(f)

    # By default, the keys will be loaded as strings, but
    # they are expected to be integers later in the notebook.
    cid_parent = { int(k):v for k,v in cid_parent.items()}
        
    if ( len(cid_parent) != len(cid_multicompo) ) :
        print("CID counts mismatch:", len(cid_multicompo), "cid_multicompo", len(cid_parent), "cid_parent")

else:

    for i in range(0, len(cid_multicompo)) :

        try:
        
            mycid = cid_multicompo[i]
            url = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str(mycid) + '/cids/TXT?cids_type=parent')
            res = urllib.request.urlopen(url)
            parent = res.read()
            cid_parent[ mycid ] = int(parent.decode().rstrip())
    
        except:
    
            cid_parent[ mycid ] = None
    
        if (i % 5 == 0 ) : time.sleep(1)
        if (i % 200 == 0 ) : print("processing ", i , "of ", len(cid_multicompo))

    print("# Download of parent CIDs has been complete")

    with open('cid_parent.json', 'w') as f:
        json.dump(cid_parent, f)
    
print("# len(cid_parent):", len(cid_parent) )
# Out:
# CID counts mismatch: 195 cid_multicompo 1748 cid_parent
# # len(cid_parent): 1748

# %%
# Store CIDs without parent compounds.
cid_noparent = [ key for key,val in cid_parent.items() if not val  ]
print(len(cid_noparent))
# Out:
# 207

# %%
#Making copy of antag_pre
antag_cov = antag_pre

#dropping rows where covalent unit count is = 1
antag_cov = antag_cov[antag_cov.CovalentUnitCount != 1]
antag_cov.shape
#228 multicomponent CIDs (2844 total)
# Out:
# (228, 3)

# %%
#getting CID list of multicomponent compounds
CID_list_multi = antag_cov['PUBCHEM_CID'].tolist()

# %%
#Getting list of covalent unit number for the multicomponent compounds
list_cov_multi = antag_cov['CovalentUnitCount'].tolist()

parent_CID_list = []
i = 0
while i < len(CID_list_multi):
    try:
    # (list_cov_multi[i] == '2'):
        url1 = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str(CID_list_multi[i]) + '/cids/TXT?cids_type=parent'
        html1 = urlopen(url1) 
        soup1 = BeautifulSoup(html1, 'lxml')
        parent1 = soup1.get_text()
        #print(parent1)
        parent_CID_list.append(parent1)
        i = i + 1
       # else:
        #    i = i + 1
    except:
        #contine
        #print('eek')
        #if err.code == ('404: PUGREST.NotFound'):
        parent_CID_list.append('0')
        i = i + 1
        



len(parent_CID_list)
# Out:
# 228

# %%
#Removing '\n from the end of each CID in parent_CID_list'
bad_chars = ['\n']

i = 0
while i < len(parent_CID_list):
    if parent_CID_list[i] == '0':
        i = i + 1
    else:
        for j in bad_chars: 
            parent_CID_list[i] = parent_CID_list[i].replace(j, '')
            i = i + 1

# %%
#adding parent_CID's to antag_cov DF
antag_cov['Parent_CIDs'] = parent_CID_list

# %%
#now that we have a list of the parent compounds for each multiple component molecule we:
#delete all values with a parent of 0
#make a new df called antag_multi_to_parent
antag_multi_to_parent = antag_cov.drop(antag_cov.loc[antag_cov['Parent_CIDs'] == '0'].index)

##replace PUBCHEM_CID with parent CID's
###Drop CID column and rename Parent_CID's to just PUBCHEM_CID
antag_multi_to_parent = antag_multi_to_parent.drop(columns = ['PUBCHEM_CID'], axis = 1)
antag_multi_to_parent = antag_multi_to_parent.rename(index=str, columns={"Parent_CIDs" : "PUBCHEM_CID"})

# %%
#Removing all CID's with multicomponent compounds from antag_pre (original DF of all antag compounds)
antag_pre_minus_multi = antag_pre[~antag_pre.PUBCHEM_CID.isin(CID_list_multi)]

# %%
#Combining antag_pre with antag_multi_to_parent
antag = antag_pre_minus_multi.append(antag_multi_to_parent)

# %%
antag_pre = antag
antag_pre.shape
# Out:
# (2844, 3)

# %% [markdown]
# # Dealing with conflicts (antag)

# %%
antag_pre['Activity Summary'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\singhs29\appdata\local\continuum\anaconda3\envs\my-rdkit-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Activity Summary'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-b97ef8f6e2df> in <module>
# ----> 1 antag_pre['Activity Summary'].value_counts()
#
# c:\users\singhs29\appdata\local\continuum\anaconda3\envs\my-rdkit-env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# c:\users\singhs29\appdata\local\continuum\anaconda3\envs\my-rdkit-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Activity Summary'

# %%
antag_pre[ 'PUBCHEM_CID'].head(10)
# Out:
# 5        5995
# 6       26041
# 8     5281575
# 9     5280795
# 10       7529
# 11       8419
# 12      62969
# 13      10215
# 14      61186
# 15       8061
# Name: PUBCHEM_CID, dtype: int32

# %%
# Generate unique CID list
antag_cid = antag_pre['PUBCHEM_CID'].tolist()

# Drop the CIDs with conflicting activity declaration.
for mycid in antag_cid :
    
    activities = set( antag_pre[ antag_pre['PUBCHEM_CID'] == mycid].loc[:,'Activity Summary'].tolist())
    if ( len(activities) > 1 ):
        #print(mycid, len(activities), activities)
        antag_pre = antag_pre[ antag_pre['PUBCHEM_CID'] != mycid ]

# %%
antag_pre.shape
# Out:
# (2858, 114)

# %%
antag_pre
# Out:
#      PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME  \
# 5                     1   11112138.0       5995.0                   Active
# 6                     2   17388662.0      26041.0             Inconclusive
# 7                     3   17388663.0    5281576.0             Inconclusive
# 8                     4   17388664.0    5281575.0             Inconclusive
# 9                     5   17388665.0    5280795.0             Inconclusive
# 10                    6   17388666.0       7529.0                 Inactive
# 11                    7   17388667.0       8419.0                 Inactive
# 12                    8   17388668.0      62969.0                 Inactive
# 13                    9   17388669.0      10215.0                 Inactive
# 14                   10   17388670.0      61186.0                 Inactive
# 15                   11   17388671.0       8061.0             Inconclusive
# 16                   12   17388672.0    6440940.0                 Inactive
# 17                   13   17388673.0      66449.0                 Inactive
# 18                   14   17388674.0      33133.0                 Inactive
# 19                   15   17388675.0       5590.0             Inconclusive
# 20                   16   17388676.0      18725.0                 Inactive
# 21                   17   17388677.0       8783.0                 Inactive
# 22                   18   17388678.0      17142.0             Inconclusive
# 23                   19   17388679.0       7540.0                 Inactive
# 24                   20   17388680.0      11776.0                 Inactive
# 25                   21   17388681.0       5569.0             Inconclusive
# 26                   22   17388682.0       6535.0                 Inactive
# 27                   23   17388683.0       6420.0                 Inactive
# 28                   24   17388684.0       6421.0                 Inactive
# 29                   25   17388685.0      13931.0                 Inactive
# 30                   26   17388686.0       5541.0             Inconclusive
# 31                   27   17388687.0     638015.0             Inconclusive
# 32                   28   17388688.0     641240.0                 Inactive
# 33                   29   17388689.0     638186.0                 Inactive
# 34                   30   17388690.0       1140.0                 Inactive
# ...                 ...          ...          ...                      ...
# 2833               2829   50113116.0      91770.0             Inconclusive
# 2834               2830   50113117.0      54740.0             Inconclusive
# 2835               2831   50113119.0      39223.0             Inconclusive
# 2836               2832   50113120.0   11409499.0                 Inactive
# 2837               2833   50113121.0      52999.0                 Inactive
# 2838               2834   50113122.0       8227.0             Inconclusive
# 2839               2835   50113123.0       8575.0             Inconclusive
# 2840               2836   50113124.0      86443.0             Inconclusive
# 2841               2837   50113125.0      39327.0                 Inactive
# 2842               2838   50113127.0    9868965.0             Inconclusive
# 2843               2839   50113129.0      32154.0                 Inactive
# 2844               2840   50113132.0      53518.0             Inconclusive
# 2845               2841   50113134.0   22833506.0             Inconclusive
# 2846               2842   50113135.0      30692.0             Inconclusive
# 2847               2843   50113136.0      86354.0             Inconclusive
# 2848               2844   50113137.0       5543.0                 Inactive
# 2849               2845   50113139.0      73282.0                 Inactive
# 2850               2846   50113143.0    3034368.0             Inconclusive
# 2851               2847   50126361.0     444795.0             Inconclusive
# 2852               2848   50126362.0     444795.0                 Inactive
# 2853               2849   50126363.0       2708.0                 Inactive
# 2854               2850   50126364.0       4909.0                 Inactive
# 2855               2851   50126365.0       3488.0                 Inactive
# 2856               2852   50126366.0     445154.0             Inconclusive
# 2857               2853   50126367.0       3715.0                 Inactive
# 2858               2854   50126368.0     443939.0             Inconclusive
# 2859               2855   50126369.0    5281708.0                 Inactive
# 2860               2856   84986994.0      10788.0                 Inactive
# 2861               2857   84986995.0      12901.0                 Inactive
# 2862               2858   84986996.0       6872.0             Inconclusive
#
#       PUBCHEM_ACTIVITY_SCORE  \
# 5                       40.0
# 6                       10.0
# 7                       20.0
# 8                       10.0
# 9                       20.0
# 10                       0.0
# 11                       0.0
# 12                       0.0
# 13                       0.0
# 14                       0.0
# 15                      10.0
# 16                       0.0
# 17                       0.0
# 18                       0.0
# 19                      10.0
# 20                       0.0
# 21                       0.0
# 22                      10.0
# 23                       0.0
# 24                       0.0
# 25                      10.0
# 26                       0.0
# 27                       0.0
# 28                       0.0
# 29                       0.0
# 30                      10.0
# 31                      10.0
# 32                       0.0
# 33                       0.0
# 34                       0.0
# ...                      ...
# 2833                    10.0
# 2834                    10.0
# 2835                    10.0
# 2836                     0.0
# 2837                     0.0
# 2838                    10.0
# 2839                    10.0
# 2840                    10.0
# 2841                     0.0
# 2842                    10.0
# 2843                     0.0
# 2844                    10.0
# 2845                    10.0
# 2846                    10.0
# 2847                    10.0
# 2848                     0.0
# 2849                     0.0
# 2850                    10.0
# 2851                    10.0
# 2852                     0.0
# 2853                     0.0
# 2854                     0.0
# 2855                     0.0
# 2856                    10.0
# 2857                     0.0
# 2858                    10.0
# 2859                     0.0
# 2860                     0.0
# 2861                     0.0
# 2862                    10.0
#
#                                    PUBCHEM_ACTIVITY_URL  \
# 5     http://assay.nih.gov/htsws/rest/display/nucrec...
# 6     http://assay.nih.gov/htsws/rest/display/nucrec...
# 7     http://assay.nih.gov/htsws/rest/display/nucrec...
# 8     http://assay.nih.gov/htsws/rest/display/nucrec...
# 9     http://assay.nih.gov/htsws/rest/display/nucrec...
# 10    http://assay.nih.gov/htsws/rest/display/nucrec...
# 11    http://assay.nih.gov/htsws/rest/display/nucrec...
# 12    http://assay.nih.gov/htsws/rest/display/nucrec...
# 13    http://assay.nih.gov/htsws/rest/display/nucrec...
# 14    http://assay.nih.gov/htsws/rest/display/nucrec...
# 15    http://assay.nih.gov/htsws/rest/display/nucrec...
# 16    http://assay.nih.gov/htsws/rest/display/nucrec...
# 17    http://assay.nih.gov/htsws/rest/display/nucrec...
# 18    http://assay.nih.gov/htsws/rest/display/nucrec...
# 19    http://assay.nih.gov/htsws/rest/display/nucrec...
# 20    http://assay.nih.gov/htsws/rest/display/nucrec...
# 21    http://assay.nih.gov/htsws/rest/display/nucrec...
# 22    http://assay.nih.gov/htsws/rest/display/nucrec...
# 23    http://assay.nih.gov/htsws/rest/display/nucrec...
# 24    http://assay.nih.gov/htsws/rest/display/nucrec...
# 25    http://assay.nih.gov/htsws/rest/display/nucrec...
# 26    http://assay.nih.gov/htsws/rest/display/nucrec...
# 27    http://assay.nih.gov/htsws/rest/display/nucrec...
# 28    http://assay.nih.gov/htsws/rest/display/nucrec...
# 29    http://assay.nih.gov/htsws/rest/display/nucrec...
# 30    http://assay.nih.gov/htsws/rest/display/nucrec...
# 31    http://assay.nih.gov/htsws/rest/display/nucrec...
# 32    http://assay.nih.gov/htsws/rest/display/nucrec...
# 33    http://assay.nih.gov/htsws/rest/display/nucrec...
# 34    http://assay.nih.gov/htsws/rest/display/nucrec...
# ...                                                 ...
# 2833  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2834  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2835  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2836  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2837  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2838  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2839  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2840  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2841  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2842  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2843  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2844  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2845  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2846  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2847  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2848  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2849  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2850  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2851  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2852  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2853  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2854  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2855  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2856  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2857  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2858  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2859  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2860  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2861  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2862  http://assay.nih.gov/htsws/rest/display/nucrec...
#
#       PUBCHEM_ASSAYDATA_COMMENT     Phenotype  Potency Efficacy  ...  \
# 5                           NaN     Inhibitor  31.6228  78.6174  ...
# 6                           NaN     Cytotoxic  44.6684  71.0657  ...
# 7                           NaN     Inhibitor  44.6684  120.437  ...
# 8                           NaN  Inconclusive      NaN      NaN  ...
# 9                           NaN     Inhibitor  50.1187  93.3465  ...
# 10                          NaN      Inactive      NaN      NaN  ...
# 11                          NaN      Inactive      NaN      NaN  ...
# 12                          NaN      Inactive      NaN      NaN  ...
# 13                          NaN      Inactive      NaN      NaN  ...
# 14                          NaN      Inactive      NaN      NaN  ...
# 15                          NaN  Inconclusive      NaN      NaN  ...
# 16                          NaN      Inactive      NaN      NaN  ...
# 17                          NaN      Inactive      NaN      NaN  ...
# 18                          NaN      Inactive      NaN      NaN  ...
# 19                          NaN     Activator  12.5893  117.915  ...
# 20                          NaN      Inactive      NaN      NaN  ...
# 21                          NaN      Inactive      NaN      NaN  ...
# 22                          NaN  Inconclusive      NaN      NaN  ...
# 23                          NaN      Inactive      NaN      NaN  ...
# 24                          NaN      Inactive      NaN      NaN  ...
# 25                          NaN  Inconclusive      NaN      NaN  ...
# 26                          NaN      Inactive      NaN      NaN  ...
# 27                          NaN      Inactive      NaN      NaN  ...
# 28                          NaN      Inactive      NaN      NaN  ...
# 29                          NaN      Inactive      NaN      NaN  ...
# 30                          NaN     Activator  50.1187  34.8991  ...
# 31                          NaN  Inconclusive      NaN      NaN  ...
# 32                          NaN      Inactive      NaN      NaN  ...
# 33                          NaN      Inactive      NaN      NaN  ...
# 34                          NaN      Inactive      NaN      NaN  ...
# ...                         ...           ...      ...      ...  ...
# 2833                        NaN  Inconclusive      NaN      NaN  ...
# 2834                        NaN  Inconclusive      NaN      NaN  ...
# 2835                        NaN  Inconclusive      NaN      NaN  ...
# 2836                        NaN      Inactive      NaN      NaN  ...
# 2837                        NaN      Inactive      NaN      NaN  ...
# 2838                        NaN     Activator  44.6684  77.9828  ...
# 2839                        NaN  Inconclusive      NaN      NaN  ...
# 2840                        NaN  Inconclusive      NaN      NaN  ...
# 2841                        NaN      Inactive      NaN      NaN  ...
# 2842                        NaN  Inconclusive      NaN      NaN  ...
# 2843                        NaN      Inactive      NaN      NaN  ...
# 2844                        NaN  Inconclusive      NaN      NaN  ...
# 2845                        NaN  Inconclusive      NaN      NaN  ...
# 2846                        NaN  Inconclusive      NaN      NaN  ...
# 2847                        NaN  Inconclusive      NaN      NaN  ...
# 2848                        NaN      Inactive      NaN      NaN  ...
# 2849                        NaN      Inactive      NaN      NaN  ...
# 2850                        NaN   Fluorescent  35.4813  41.2641  ...
# 2851                        NaN  Inconclusive      NaN      NaN  ...
# 2852                        NaN      Inactive      NaN      NaN  ...
# 2853                        NaN      Inactive      NaN      NaN  ...
# 2854                        NaN      Inactive      NaN      NaN  ...
# 2855                        NaN      Inactive      NaN      NaN  ...
# 2856                        NaN     Cytotoxic  28.1838  45.9258  ...
# 2857                        NaN      Inactive      NaN      NaN  ...
# 2858                        NaN  Inconclusive      NaN      NaN  ...
# 2859                        NaN      Inactive      NaN      NaN  ...
# 2860                        NaN      Inactive      NaN      NaN  ...
# 2861                        NaN      Inactive      NaN      NaN  ...
# 2862                        NaN  Inconclusive      NaN      NaN  ...
#
#      W530-Activity at 76.79 uM W530-Activity at 182.0 uM  \
# 5                      11.7811                       NaN
# 6                     -59.2214                       NaN
# 7                      -4.1477                       NaN
# 8                     -14.1564                       NaN
# 9                      25.4583                       NaN
# 10                      4.8262                       NaN
# 11                     -5.5875                       NaN
# 12                     -3.7658                       NaN
# 13                     -7.9807                       NaN
# 14                    -10.3251                       NaN
# 15                      7.4582                       NaN
# 16                     -2.8949                       NaN
# 17                    -12.3206                       NaN
# 18                     14.2439                       NaN
# 19                    -20.5746                       NaN
# 20                      8.9909                       NaN
# 21                     -1.9665                       NaN
# 22                    -22.1232                       NaN
# 23                     -6.7427                       NaN
# 24                      2.4073                       NaN
# 25                      -3.021                       NaN
# 26                     -3.1829                       NaN
# 27                      0.2173                       NaN
# 28                      6.9337                       NaN
# 29                     10.2708                       NaN
# 30                     -5.7389                       NaN
# 31                    -27.9781                       NaN
# 32                     -9.0078                       NaN
# 33                     -6.2014                       NaN
# 34                       2.254                       NaN
# ...                        ...                       ...
# 2833                   13.1227                       NaN
# 2834                   12.3621                       NaN
# 2835                   12.5621                       NaN
# 2836                    2.3716                       NaN
# 2837                   16.2928                       NaN
# 2838                   21.8002                       NaN
# 2839                    4.6853                       NaN
# 2840                   15.0741                       NaN
# 2841                   13.3066                       NaN
# 2842                    5.3978                       NaN
# 2843                   10.4495                       NaN
# 2844                   17.1501                       NaN
# 2845                   26.2609                       NaN
# 2846                   12.9534                       NaN
# 2847                   15.8888                       NaN
# 2848                    1.5309                       NaN
# 2849                   -5.9288                       NaN
# 2850                    33.393                       NaN
# 2851                  -15.3099                       NaN
# 2852                   24.1541                       NaN
# 2853                   -0.9246                       NaN
# 2854                  -10.2432                       NaN
# 2855                    1.6824                       NaN
# 2856                  -34.9381                       NaN
# 2857                   20.4258                       NaN
# 2858                    -0.657                       NaN
# 2859                   -5.9722                       NaN
# 2860                  -25.6861                       NaN
# 2861                   -20.647                       NaN
# 2862                  -17.4464                       NaN
#
#      W530-Activity at 407.0 uM W530-Activity at 910.0 uM  \
# 5                          NaN                       NaN
# 6                          NaN                       NaN
# 7                          NaN                       NaN
# 8                          NaN                       NaN
# 9                          NaN                       NaN
# 10                         NaN                       NaN
# 11                         NaN                       NaN
# 12                         NaN                       NaN
# 13                         NaN                       NaN
# 14                         NaN                       NaN
# 15                         NaN                       NaN
# 16                         NaN                       NaN
# 17                         NaN                       NaN
# 18                         NaN                       NaN
# 19                         NaN                       NaN
# 20                         NaN                       NaN
# 21                         NaN                       NaN
# 22                         NaN                       NaN
# 23                         NaN                       NaN
# 24                         NaN                       NaN
# 25                         NaN                       NaN
# 26                         NaN                       NaN
# 27                         NaN                       NaN
# 28                         NaN                       NaN
# 29                         NaN                       NaN
# 30                         NaN                       NaN
# 31                         NaN                       NaN
# 32                         NaN                       NaN
# 33                         NaN                       NaN
# 34                         NaN                       NaN
# ...                        ...                       ...
# 2833                       NaN                       NaN
# 2834                       NaN                       NaN
# 2835                       NaN                       NaN
# 2836                       NaN                       NaN
# 2837                       NaN                       NaN
# 2838                       NaN                       NaN
# 2839                       NaN                       NaN
# 2840                       NaN                       NaN
# 2841                       NaN                       NaN
# 2842                       NaN                       NaN
# 2843                       NaN                       NaN
# 2844                       NaN                       NaN
# 2845                       NaN                       NaN
# 2846                       NaN                       NaN
# 2847                       NaN                       NaN
# 2848                       NaN                       NaN
# 2849                       NaN                       NaN
# 2850                       NaN                       NaN
# 2851                       NaN                       NaN
# 2852                       NaN                       NaN
# 2853                       NaN                       NaN
# 2854                       NaN                       NaN
# 2855                       NaN                       NaN
# 2856                       NaN                       NaN
# 2857                       NaN                       NaN
# 2858                       NaN                       NaN
# 2859                       NaN                       NaN
# 2860                       NaN                       NaN
# 2861                       NaN                       NaN
# 2862                       NaN                       NaN
#
#      W530-Activity at 2034.7 uM W530-Activity at 4832.4 uM  \
# 5                           NaN                        NaN
# 6                           NaN                        NaN
# 7                           NaN                        NaN
# 8                           NaN                        NaN
# 9                           NaN                        NaN
# 10                          NaN                        NaN
# 11                          NaN                        NaN
# 12                          NaN                        NaN
# 13                          NaN                        NaN
# 14                          NaN                        NaN
# 15                          NaN                        NaN
# 16                          NaN                        NaN
# 17                          NaN                        NaN
# 18                          NaN                        NaN
# 19                          NaN                        NaN
# 20                          NaN                        NaN
# 21                          NaN                        NaN
# 22                          NaN                        NaN
# 23                          NaN                        NaN
# 24                          NaN                        NaN
# 25                          NaN                        NaN
# 26                          NaN                        NaN
# 27                          NaN                        NaN
# 28                          NaN                        NaN
# 29                          NaN                        NaN
# 30                          NaN                        NaN
# 31                          NaN                        NaN
# 32                          NaN                        NaN
# 33                          NaN                        NaN
# 34                          NaN                        NaN
# ...                         ...                        ...
# 2833                        NaN                        NaN
# 2834                        NaN                        NaN
# 2835                        NaN                        NaN
# 2836                        NaN                        NaN
# 2837                        NaN                        NaN
# 2838                        NaN                        NaN
# 2839                        NaN                        NaN
# 2840                        NaN                        NaN
# 2841                        NaN                        NaN
# 2842                        NaN                        NaN
# 2843                        NaN                        NaN
# 2844                        NaN                        NaN
# 2845                        NaN                        NaN
# 2846                        NaN                        NaN
# 2847                        NaN                        NaN
# 2848                        NaN                        NaN
# 2849                        NaN                        NaN
# 2850                        NaN                        NaN
# 2851                        NaN                        NaN
# 2852                        NaN                        NaN
# 2853                        NaN                        NaN
# 2854                        NaN                        NaN
# 2855                        NaN                        NaN
# 2856                        NaN                        NaN
# 2857                        NaN                        NaN
# 2858                        NaN                        NaN
# 2859                        NaN                        NaN
# 2860                        NaN                        NaN
# 2861                        NaN                        NaN
# 2862                        NaN                        NaN
#
#      W530-Activity at 10805.3 uM W530-Activity at 24160.5 uM  \
# 5                            NaN                         NaN
# 6                            NaN                         NaN
# 7                            NaN                         NaN
# 8                            NaN                         NaN
# 9                            NaN                         NaN
# 10                           NaN                         NaN
# 11                           NaN                         NaN
# 12                           NaN                         NaN
# 13                           NaN                         NaN
# 14                           NaN                         NaN
# 15                           NaN                         NaN
# 16                           NaN                         NaN
# 17                           NaN                         NaN
# 18                           NaN                         NaN
# 19                           NaN                         NaN
# 20                           NaN                         NaN
# 21                           NaN                         NaN
# 22                           NaN                         NaN
# 23                           NaN                         NaN
# 24                           NaN                         NaN
# 25                           NaN                         NaN
# 26                           NaN                         NaN
# 27                           NaN                         NaN
# 28                           NaN                         NaN
# 29                           NaN                         NaN
# 30                           NaN                         NaN
# 31                           NaN                         NaN
# 32                           NaN                         NaN
# 33                           NaN                         NaN
# 34                           NaN                         NaN
# ...                          ...                         ...
# 2833                         NaN                         NaN
# 2834                         NaN                         NaN
# 2835                         NaN                         NaN
# 2836                         NaN                         NaN
# 2837                         NaN                         NaN
# 2838                         NaN                         NaN
# 2839                         NaN                         NaN
# 2840                         NaN                         NaN
# 2841                         NaN                         NaN
# 2842                         NaN                         NaN
# 2843                         NaN                         NaN
# 2844                         NaN                         NaN
# 2845                         NaN                         NaN
# 2846                         NaN                         NaN
# 2847                         NaN                         NaN
# 2848                         NaN                         NaN
# 2849                         NaN                         NaN
# 2850                         NaN                         NaN
# 2851                         NaN                         NaN
# 2852                         NaN                         NaN
# 2853                         NaN                         NaN
# 2854                         NaN                         NaN
# 2855                         NaN                         NaN
# 2856                         NaN                         NaN
# 2857                         NaN                         NaN
# 2858                         NaN                         NaN
# 2859                         NaN                         NaN
# 2860                         NaN                         NaN
# 2861                         NaN                         NaN
# 2862                         NaN                         NaN
#
#      W530-Activity at 54023.0 uM           Compound QC
# 5                            NaN     QC'd by Prestwick
# 6                            NaN     QC'd by NIEHS/NTP
# 7                            NaN     QC'd by NIEHS/NTP
# 8                            NaN     QC'd by NIEHS/NTP
# 9                            NaN     QC'd by NIEHS/NTP
# 10                           NaN     QC'd by NIEHS/NTP
# 11                           NaN     QC'd by NIEHS/NTP
# 12                           NaN     QC'd by NIEHS/NTP
# 13                           NaN     QC'd by NIEHS/NTP
# 14                           NaN     QC'd by NIEHS/NTP
# 15                           NaN     QC'd by NIEHS/NTP
# 16                           NaN     QC'd by NIEHS/NTP
# 17                           NaN     QC'd by NIEHS/NTP
# 18                           NaN     QC'd by NIEHS/NTP
# 19                           NaN     QC'd by NIEHS/NTP
# 20                           NaN     QC'd by NIEHS/NTP
# 21                           NaN     QC'd by NIEHS/NTP
# 22                           NaN     QC'd by NIEHS/NTP
# 23                           NaN     QC'd by NIEHS/NTP
# 24                           NaN     QC'd by NIEHS/NTP
# 25                           NaN     QC'd by NIEHS/NTP
# 26                           NaN     QC'd by NIEHS/NTP
# 27                           NaN     QC'd by NIEHS/NTP
# 28                           NaN     QC'd by NIEHS/NTP
# 29                           NaN     QC'd by NIEHS/NTP
# 30                           NaN     QC'd by NIEHS/NTP
# 31                           NaN     QC'd by NIEHS/NTP
# 32                           NaN     QC'd by NIEHS/NTP
# 33                           NaN     QC'd by NIEHS/NTP
# 34                           NaN     QC'd by NIEHS/NTP
# ...                          ...                   ...
# 2833                         NaN           QC'd by EPA
# 2834                         NaN           QC'd by EPA
# 2835                         NaN           QC'd by EPA
# 2836                         NaN           QC'd by EPA
# 2837                         NaN           QC'd by EPA
# 2838                         NaN           QC'd by EPA
# 2839                         NaN           QC'd by EPA
# 2840                         NaN           QC'd by EPA
# 2841                         NaN           QC'd by EPA
# 2842                         NaN           QC'd by EPA
# 2843                         NaN           QC'd by EPA
# 2844                         NaN           QC'd by EPA
# 2845                         NaN           QC'd by EPA
# 2846                         NaN           QC'd by EPA
# 2847                         NaN           QC'd by EPA
# 2848                         NaN           QC'd by EPA
# 2849                         NaN           QC'd by EPA
# 2850                         NaN           QC'd by EPA
# 2851                         NaN           QC'd by EPA
# 2852                         NaN  QC'd by SigmaAldrich
# 2853                         NaN  QC'd by SigmaAldrich
# 2854                         NaN  QC'd by SigmaAldrich
# 2855                         NaN  QC'd by SigmaAldrich
# 2856                         NaN  QC'd by SigmaAldrich
# 2857                         NaN  QC'd by SigmaAldrich
# 2858                         NaN  QC'd by SigmaAldrich
# 2859                         NaN  QC'd by SigmaAldrich
# 2860                         NaN        QC'd by DPISMR
# 2861                         NaN        QC'd by DPISMR
# 2862                         NaN        QC'd by DPISMR
#
# [2858 rows x 114 columns]

# %%
antag_pre['Activity Summary'].value_counts()
# Out:
# Inactive        1914
# Inconclusive     561
# Active            50
# Name: Activity Summary, dtype: int64

# %% [markdown]
# # Data Cleaning Full (ag)

# %% [markdown]
# Read the antagonist assay data into a data frame

# %%
#Reading in Summary ANTAGONIST CSV
ag_pre = pd.read_csv('AID_588532_datatable_all.csv')
ag_pre = ag_pre.iloc[1:]
ag_pre.tail(3)
# Out:
#      PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME  \
# 2860               2856   84986994.0      10788.0             Inconclusive
# 2861               2857   84986995.0      12901.0                 Inactive
# 2862               2858   84986996.0       6872.0                 Inactive
#
#       PUBCHEM_ACTIVITY_SCORE  \
# 2860                    10.0
# 2861                     0.0
# 2862                     0.0
#
#                                    PUBCHEM_ACTIVITY_URL  \
# 2860  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2861  http://assay.nih.gov/htsws/rest/display/nucrec...
# 2862  http://assay.nih.gov/htsws/rest/display/nucrec...
#
#       PUBCHEM_ASSAYDATA_COMMENT     Phenotype Potency Efficacy  ...  \
# 2860                        NaN  Inconclusive  0.0126   30.825  ...
# 2861                        NaN      Inactive     NaN      NaN  ...
# 2862                        NaN      Inactive     NaN      NaN  ...
#
#      W530-Activity at 76.79 uM W530-Activity at 182.0 uM  \
# 2860                   18.5654                       NaN
# 2861                   -1.7271                       NaN
# 2862                  -19.5112                       NaN
#
#      W530-Activity at 407.0 uM W530-Activity at 910.0 uM  \
# 2860                       NaN                       NaN
# 2861                       NaN                       NaN
# 2862                       NaN                       NaN
#
#      W530-Activity at 2034.7 uM W530-Activity at 4832.4 uM  \
# 2860                        NaN                        NaN
# 2861                        NaN                        NaN
# 2862                        NaN                        NaN
#
#      W530-Activity at 10805.3 uM W530-Activity at 24160.5 uM  \
# 2860                         NaN                         NaN
# 2861                         NaN                         NaN
# 2862                         NaN                         NaN
#
#      W530-Activity at 54023.0 uM     Compound QC
# 2860                         NaN  QC'd by DPISMR
# 2861                         NaN  QC'd by DPISMR
# 2862                         NaN  QC'd by DPISMR
#
# [3 rows x 114 columns]

# %%
ag_pre = ag_pre[['PUBCHEM_CID', 'PUBCHEM_ACTIVITY_OUTCOME', 'Activity Summary', 'Ratio Potency (uM)', 'Ratio Efficacy (%)']]
ag_pre.tail(3)
# Out:
#        PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME Activity Summary  \
# 10487       5794.0                 Inactive         inactive
# 10488    3034285.0                 Inactive         inactive
# 10489       6623.0                 Inactive         inactive
#
#       Ratio Potency (uM) Ratio Efficacy (%)
# 10487                NaN                  0
# 10488                NaN                  0
# 10489                NaN                  0

# %% [markdown]
# Deal with the NULL values: remove the rows without CIDs.

# %%
ag_pre.isnull().sum()
# Out:
# PUBCHEM_CID                  150
# PUBCHEM_ACTIVITY_OUTCOME       1
# Activity Summary               1
# Ratio Potency (uM)          9685
# Ratio Efficacy (%)             1
# dtype: int64

# %%
ag_pre = ag_pre[ ag_pre['PUBCHEM_CID'].notnull() ]
ag_pre.shape
# Out:
# (10337, 5)

# %% [markdown]
# Convert the PUBCHEM_CID (floats) into an integer type.

# %%
ag_pre['PUBCHEM_CID'] = ag_pre['PUBCHEM_CID'].astype(int)
ag_pre.head(3)
# Out:
#    PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME Activity Summary Ratio Potency (uM)  \
# 4     12850184                 Inactive         inactive                NaN
# 5        89753                 Inactive         inactive                NaN
# 6         9403             Inconclusive     inconclusive                NaN
#
#   Ratio Efficacy (%)
# 4                  0
# 5                  0
# 6                  0

# %%
ag_pre['Activity Summary'].value_counts()
# Out:
# inactive                              9043
# inconclusive                           882
# active agonist                         211
# inconclusive agonist                    81
# active antagonist                       53
# inconclusive antagonist                 44
# inconclusive agonist (fluorescent)      23
# Name: Activity Summary, dtype: int64

# %%
ag_pre['PUBCHEM_ACTIVITY_OUTCOME'].value_counts()
# Out:
# Inactive        9043
# Inconclusive    1083
# Active           211
# Name: PUBCHEM_ACTIVITY_OUTCOME, dtype: int64

# %%
ag_pre.shape
# Out:
# (10337, 5)

# %%
ag_pre.head(3)
# Out:
#    PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME Activity Summary Ratio Potency (uM)  \
# 4     12850184                 Inactive         inactive                NaN
# 5        89753                 Inactive         inactive                NaN
# 6         9403             Inconclusive     inconclusive                NaN
#
#   Ratio Efficacy (%)
# 4                  0
# 5                  0
# 6                  0

# %% [markdown]
# # Identifying Covalent Unit Count (ag)

# %% [markdown]
# Compute the number of CID chunks based on the number of CIDs and the chunk size.

# %%
chunk_size = 200
num_cids = len(ag_pre['PUBCHEM_CID'])

if num_cids % chunk_size == 0 :
    num_chunks = int( num_cids / chunk_size )
else :
    num_chunks = int( num_cids / chunk_size ) + 1

print("# CIDs = ", num_cids)
print("# CID Chunks = ", num_chunks, "(chunked by ", chunk_size, ")")
# Out:
# # CIDs =  10337
# # CID Chunks =  52 (chunked by  200 )

# %% [markdown]
# Retrieve the covalent unit counts for each chunk of CIDs.

# %%
import time

frames = []  # temporary list to store data frames from each PUG-REST request.

#print("chunkid", 'idx1', 'idx2', 'length', sep="\t")

for i in range(0, num_chunks) :
    
    idx1 = chunk_size * i
    idx2 = chunk_size * (i + 1)
    cidstr = ",".join(ag_pre.PUBCHEM_CID[idx1:idx2].astype(str).tolist())

    url = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + cidstr + '/property/CovalentUnitCount/TXT')
    data = pd.read_csv( urllib.request.urlopen(url), header=None, names=['cov_units'] )
    frames.append(data)
    
    # Uncomment this line to check the progress
    #print(i, idx1, idx2, len(data), sep="\t")
    
    if (i % 5 == 0 ) :
        time.sleep(1)  # To comply with the PubChem usage polocy (no more than 5 requests per sec)

#    if ( i == 2 ) : break  #- for debugging

cov_units = pd.concat(frames,ignore_index=True)
print(cov_units.shape)
# Out:
# (10337, 1)

# %% [markdown]
# # Dealing with Multicomponent Molecules (ag)

# %%
ag_pre['CovalentUnitCount'] = cov_units.cov_units.tolist()
ag_pre.CovalentUnitCount.isnull().sum()
# Out:
# 0

# %%
ag_pre['CovalentUnitCount'].value_counts()
# Out:
# 1     8308
# 2     1560
# 3      348
# 5       49
# 4       43
# 6       10
# 9        6
# 7        5
# 12       2
# 11       2
# 8        2
# 10       1
# 41       1
# Name: CovalentUnitCount, dtype: int64

# %%
cid_multicompo = ag_pre[ ag_pre.CovalentUnitCount > 1 ].PUBCHEM_CID.tolist()
len(cid_multicompo)
# Out:
# 2029

# %% [markdown]
# The multicomponent CID list has some duplicate CIDs.  Removing them will reduce the number of PUG-REST requests later.

# %%
cid_multicompo.sort()
 
cid_multicompo_uniq = sorted( set(cid_multicompo) )
cid_multicompo_dup = []
    
for mycid in cid_multicompo_uniq:
        if ( cid_multicompo.count( mycid ) > 1 ):
            cid_multicompo_dup.append( mycid )

print(len(cid_multicompo_dup))
print(cid_multicompo_dup)

cid_multicompo = cid_multicompo_uniq
# Out:
# 238
# [2767, 5795, 5807, 5935, 5946, 5963, 5974, 6014, 6099, 8152, 8478, 8638, 8667, 8691, 8715, 8722, 8753, 8813, 8816, 8870, 8980, 9279, 9280, 9351, 9373, 9409, 9703, 9787, 10866, 11048, 11057, 11065, 11224, 11313, 11545, 11693, 11933, 12447, 12456, 12484, 12525, 13144, 13266, 13506, 14184, 14250, 14710, 14842, 15106, 16013, 16015, 16230, 16961, 17170, 17730, 18340, 18487, 19379, 19458, 19518, 19604, 22420, 22584, 22960, 22985, 23392, 23394, 24434, 24482, 24502, 24633, 24639, 26041, 26758, 27461, 27503, 27872, 31202, 31280, 32731, 33286, 33557, 36605, 38852, 39424, 44072, 54891, 54900, 54911, 55182, 56704, 60496, 60560, 60714, 60754, 60822, 60934, 60962, 61100, 61444, 62311, 62581, 62655, 62882, 62884, 62935, 64142, 64927, 66245, 68589, 68624, 71412, 71587, 75311, 83823, 90473, 92151, 92965, 102428, 107882, 108005, 108938, 135242, 155434, 161803, 164457, 166033, 235227, 441244, 441308, 441325, 441337, 441374, 443939, 516871, 516919, 517121, 517326, 517383, 517414, 517546, 522325, 533728, 560256, 657201, 2723598, 2723770, 2723816, 2723854, 2724411, 2733525, 2734161, 2734171, 2734956, 3005572, 3082221, 3084014, 3270262, 3423265, 3571582, 4110039, 4343483, 4445035, 5018304, 5281064, 5284363, 5284366, 5284416, 5284441, 5284443, 5284452, 5284483, 5388983, 5462355, 5486830, 6419941, 6419978, 6420013, 6420042, 6432394, 6433339, 6435335, 6603108, 6604122, 6917728, 6918126, 6918580, 9887053, 9889168, 11074431, 11769095, 11956149, 11957572, 14720269, 15008962, 16051954, 16052011, 16220118, 16682993, 16684434, 16759173, 20055509, 23662354, 23662383, 23663403, 23665728, 23665759, 23665772, 23667299, 23667638, 23667648, 23668192, 23668193, 23668196, 23672302, 23673837, 23676704, 23676814, 23677963, 23688977, 23692768, 23702994, 23707968, 23716429, 25150753, 53316406, 54680691, 54680782, 54682468, 54685925, 54704426, 60196281, 60196285, 60196296, 60196338, 60196348, 60196372, 135465076]

# %% [markdown]
# Because downloading parent compound information through PUG-REST takes a long time, we want to store the data in a file when they are downloaded for later use. When the cell is run next time, it will read the data from the file, rather than downloading them from PubChem.

# %%
import os.path
import json

cid_parent= {}
file_parent = 'cid_parent_ag.json'

if os.path.isfile(file_parent) and os.path.getsize(file_parent) :
    
    with open(file_parent) as f:
        cid_parent = json.load(f)

    # By default, the keys will be loaded as strings, but
    # they are expected to be integers later in the notebook.
    cid_parent = { int(k):v for k,v in cid_parent.items()}
        
    if ( len(cid_parent) != len(cid_multicompo) ) :
        print("CID counts mismatch:", len(cid_multicompo), "cid_multicompo", len(cid_parent), "cid_parent")

else:

    for i in range(0, len(cid_multicompo)) :

        try:
        
            mycid = cid_multicompo[i]
            url = ('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/' + str(mycid) + '/cids/TXT?cids_type=parent')
            res = urllib.request.urlopen(url)
            parent = res.read()
            cid_parent[ mycid ] = int(parent.decode().rstrip())
    
        except:
    
            cid_parent[ mycid ] = None
    
        if (i % 5 == 0 ) : time.sleep(1)
        if (i % 200 == 0 ) : print("processing ", i , "of ", len(cid_multicompo))

    print("# Download of parent CIDs has been complete")

    with open(file_parent, 'w') as f:
        json.dump(cid_parent, f)
    
print("# len(cid_parent):", len(cid_parent) )
# Out:
# # len(cid_parent): 1748

# %%
# Store CIDs without parent compounds.
cid_noparent = [ key for key,val in cid_parent.items() if not val  ]
print(len(cid_noparent))
# Out:
# 220

# %%
# Loop over each row in the data frame
for idx, row in ag_pre.iterrows() :
    if ( row['CovalentUnitCount'] > 1 ) :
        ag_pre.loc[ idx, 'PUBCHEM_CID' ] = cid_parent[ row['PUBCHEM_CID'] ]

# %%
ag_pre.head(3)
# Out:
#    PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME Activity Summary Ratio Potency (uM)  \
# 4    5460352.0                 Inactive         inactive                NaN
# 5      10690.0                 Inactive         inactive                NaN
# 6       9403.0             Inconclusive     inconclusive                NaN
#
#   Ratio Efficacy (%)  CovalentUnitCount
# 4                  0                  3
# 5                  0                  3
# 6                  0                  1

# %%
# Double check if the substitution has been done correctly.
count_no_sub = 0
for mycid in cid_multicompo :
    x = ag_pre[ ag_pre['PUBCHEM_CID'] == mycid ]
    if ( len(x) != 0 ) :
        print("Warning:", mycid, "is still found", len(x))
        count_no_sub += 1

if ( count_no_sub == 0 ) :
    print("All multicomponent compounds have been replaced!")
else :
    print("Warning:", count_no_sub, "compound(s) have not been replaced")
# Out:
# All multicomponent compounds have been replaced!

# %%
ag_pre = ag_pre[ ag_pre['PUBCHEM_CID'].notnull() ]
ag_pre['PUBCHEM_CID'] = ag_pre['PUBCHEM_CID'].astype(int)
ag_pre.shape
# Out:
# (10088, 6)

# %%
ag_pre.head(3)
# Out:
#    PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME Activity Summary Ratio Potency (uM)  \
# 4      5460352                 Inactive         inactive                NaN
# 5        10690                 Inactive         inactive                NaN
# 6         9403             Inconclusive     inconclusive                NaN
#
#   Ratio Efficacy (%)  CovalentUnitCount
# 4                  0                  3
# 5                  0                  3
# 6                  0                  1

# %% [markdown]
# # Dealing with conflicts (ag)

# %%
ag_pre.isnull().sum()
# Out:
# PUBCHEM_CID                    0
# PUBCHEM_ACTIVITY_OUTCOME       0
# Activity Summary               0
# Ratio Potency (uM)          9352
# Ratio Efficacy (%)             0
# CovalentUnitCount              0
# dtype: int64

# %%
ag_pre['PUBCHEM_ACTIVITY_OUTCOME'].value_counts()
# Out:
# Inactive        8828
# Inconclusive    1057
# Active           203
# Name: PUBCHEM_ACTIVITY_OUTCOME, dtype: int64

# %%
ag_pre['Activity Summary'].value_counts()
# Out:
# inactive                              8828
# inconclusive                           862
# active agonist                         203
# inconclusive agonist                    80
# active antagonist                       48
# inconclusive antagonist                 44
# inconclusive agonist (fluorescent)      23
# Name: Activity Summary, dtype: int64

# %%
ag_pre[ 'PUBCHEM_CID'].head(10)
# Out:
# 4      5460352
# 5        10690
# 6         9403
# 7     13218779
# 9        16043
# 10       16043
# 11       11295
# 12     2724372
# 13      637566
# 14         994
# Name: PUBCHEM_CID, dtype: int32

# %%
# Generate unique CID list
ag_cid = ag_pre['PUBCHEM_CID'].tolist()

# Drop the CIDs with conflicting activity declaration.
for mycid in ag_cid :
    
    activities = set( ag_pre[ ag_pre['PUBCHEM_CID'] == mycid].loc[:,'Activity Summary'].tolist())
    if ( len(activities) > 1 ):
        #print(mycid, len(activities), activities)
        ag_pre = ag_pre[ ag_pre['PUBCHEM_CID'] != mycid ]

# %%
ag_pre.head(3)
# Out:
#    PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME Activity Summary Ratio Potency (uM)  \
# 4      5460352                 Inactive         inactive                NaN
# 5        10690                 Inactive         inactive                NaN
# 6         9403             Inconclusive     inconclusive                NaN
#
#   Ratio Efficacy (%)  CovalentUnitCount
# 4                  0                  3
# 5                  0                  3
# 6                  0                  1

# %%
ag_pre.shape
# Out:
# (9466, 6)

# %%
ag_pre['Activity Summary'].value_counts()
# Out:
# inactive                              8525
# inconclusive                           651
# active agonist                         172
# inconclusive agonist                    50
# active antagonist                       31
# inconclusive agonist (fluorescent)      19
# inconclusive antagonist                 18
# Name: Activity Summary, dtype: int64

# %% [markdown]
# # Combining Dataframes and Cleaning (both)

# %% [markdown]
# ## Method 1

# %%
antag_cid = antag_pre['PUBCHEM_CID'].tolist()
ag_cid = ag_pre['PUBCHEM_CID'].tolist()
all_cid = list(set( antag_cid + ag_cid ))
len(all_cid)
# Out:
# 7374

# %%
final_act = {}

for mycid in list(all_cid) :
    
    antag_act = list(set( antag_pre[ antag_pre['PUBCHEM_CID'] == mycid].loc[:,'Activity Summary'].tolist()))
    ag_act = list(set( ag_pre[ ag_pre['PUBCHEM_CID'] == mycid].loc[:,'Activity Summary'].tolist()))
    all_act = list(set( antag_act + ag_act ))
    
    if ( len(all_act) == 1) :
        final_act[ mycid ] = all_act[0]

df_activity = pd.DataFrame(final_act.items(), columns=['cid', 'activity'])
df_activity = df_activity.sort_values('cid').reset_index(drop=True)
df_activity = df_activity[ (df_activity['activity'] == 'active agonist') | \
                           (df_activity['activity'] == 'active antagonist' ) | \
                           (df_activity['activity'] == 'inactive') ]
df_activity.activity.value_counts()
# Out:
# inactive             5639
# active agonist        104
# active antagonist      30
# Name: activity, dtype: int64

# %% [markdown]
# ## Method 2 - USING

# %%
#antag_cid_df = antag_pre[ antag_pre['Activity Summary'] == 'active antagonist' ]
#ag_cid_df = ag_pre[ ag_pre['Activity Summary'] == 'active agonist' ]
#inact_cid_df_antag = antag_pre[ antag_pre['Activity Summary'] == 'inactive' ]
#inact_cid_df_ag = ag_pre[ ag_pre['Activity Summary'] == 'inactive' ]

#df_activity2 = pd.concat([ antag_cid_df, ag_cid_df, inact_cid_df_antag, inact_cid_df_ag])

# %%
cids_ant = antag_pre[ antag_pre['Activity Summary'] == 'active antagonist' ].PUBCHEM_CID.tolist()
cids_ago = ag_pre[ ag_pre['Activity Summary'] == 'active agonist' ].PUBCHEM_CID.tolist()
cids_inact1 = antag_pre[ antag_pre['Activity Summary'] == 'inactive' ].PUBCHEM_CID.tolist()
cids_inact2 = ag_pre[ ag_pre['Activity Summary'] == 'inactive' ].PUBCHEM_CID.tolist()

cids_conflict = np.intersect1d(cids_ant, cids_ago)
cids_ant = np.setdiff1d( cids_ant, cids_conflict )
cids_ago = np.setdiff1d( cids_ago, cids_conflict )

cids_inact = np.intersect1d(cids_inact1, cids_inact2)

final_act = {}

for mycid in cids_ant :
    final_act[ mycid ] = 'active antagonist'
    
for mycid in cids_ago :
    final_act[ mycid ] = 'active agonist'
    
for mycid in cids_inact :
    final_act[ mycid ] = 'inactive'

df_activity2 = pd.DataFrame(final_act.items(), columns=['cid', 'activity'])
df_activity2 = df_activity2.sort_values('cid').reset_index(drop=True)
df_activity2.activity.value_counts()
# Out:
# inactive             5263
# active antagonist     274
# active agonist        135
# Name: activity, dtype: int64

# %%
df_activity2 = df_activity2.rename(columns = {'cid' : 'PUBCHEM_CID', 'activity' : 'Activity Summary'})

# %%
#Writing df_activity2 to csv

df_activity2.to_csv('FINAL_Merged_Cleaned_CSV_7-19', index = False)
