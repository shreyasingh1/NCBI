# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
# %matplotlib inline

#hiding warning messages
import warnings
warnings.filterwarnings("ignore")
import time

# %% [markdown]
# # NB

# %%
#Reading in grep files
grep_nb = pd.read_csv('grep_nb.txt', sep = '\t')
grep_nb = grep_nb.T
grep_nb = grep_nb.reset_index()
grep_nb = grep_nb.T
grep_nb = grep_nb.reset_index(drop = True)

#converting to str (NB)
grep_nb = grep_nb.astype(str)

#splitting scores 
str_split_nb = grep_nb[1].tolist()
i = 0
while (i < len(str_split_nb)):
    str_split_nb[i] = str_split_nb[i].split()
    i = i + 1
    
#making df
scores_nb = pd.DataFrame(str_split_nb)

#label df
labels_nb = pd.DataFrame(grep_nb[0])
labels_nb = labels_nb.rename(columns = {0 : 'labels'})

#combining
data_nb = pd.concat([labels_nb, scores_nb], axis = 1)

#reindexing
data_nb = data_nb.rename(columns = {0 : 'ACC', 1 : 'AUC', 2 : 'MCC', 3 : 'SENS', 4 : 'SPHE', 5 : 'BACC',})
data_nb = data_nb.set_index('labels')

#seperating datasets into Train, Test, Ext1, Ext2, Ext3
data_nb = data_nb.iloc[:25]
data_nb.loc['output_maccs:Test']
subset_nb_train = data_nb.loc[['output_maccs:Train', 'output_top:Train', 'output_ecfp:Train', 'output_fcfp:Train', 'output_pub:Train',], :]
subset_nb_test = data_nb.loc[['output_maccs:Test', 'output_top:Test', 'output_ecfp:Test', 'output_fcfp:Test', 'output_pub:Test',], :]
subset_nb_ext1 = data_nb.loc[['output_maccs:Ext1', 'output_top:Ext1', 'output_ecfp:Ext1', 'output_fcfp:Ext1', 'output_pub:Ext1',], :]
subset_nb_ext2 = data_nb.loc[['output_maccs:Ext2', 'output_top:Ext2', 'output_ecfp:Ext2', 'output_fcfp:Ext2', 'output_pub:Ext2',], :]
subset_nb_ext3 = data_nb.loc[['output_maccs:Ext3', 'output_top:Ext3', 'output_ecfp:Ext3', 'output_fcfp:Ext3', 'output_pub:Ext3',], :]

# %% [markdown]
# # DT

# %%
#Reading in grep files
grep_dt = pd.read_csv('grep_dt.txt', sep = '\t')
grep_dt = grep_dt.T
grep_dt = grep_dt.reset_index()
grep_dt = grep_dt.T
grep_dt = grep_dt.reset_index(drop = True)

#converting to str (dt)
grep_dt = grep_dt.astype(str)

#splitting scores 
str_split_dt = grep_dt[1].tolist()
i = 0
while (i < len(str_split_dt)):
    str_split_dt[i] = str_split_dt[i].split()
    i = i + 1
    
#making df
scores_dt = pd.DataFrame(str_split_dt)

#label df
labels_dt = pd.DataFrame(grep_dt[0])
labels_dt = labels_dt.rename(columns = {0 : 'labels'})

#combining
data_dt = pd.concat([labels_dt, scores_dt], axis = 1)

#reindexing
data_dt = data_dt.rename(columns = {0 : 'ACC', 1 : 'AUC', 2 : 'MCC', 3 : 'SENS', 4 : 'SPHE', 5 : 'BACC',})
data_dt = data_dt.set_index('labels')

#seperating datasets into Train, Test, Ext1, Ext2, Ext3
data_dt = data_dt.iloc[:25]
data_dt.loc['output_maccs:Test']
subset_dt_train = data_dt.loc[['output_maccs:Train', 'output_top:Train', 'output_ecfp:Train', 'output_fcfp:Train', 'output_pub:Train',], :]
subset_dt_test = data_dt.loc[['output_maccs:Test', 'output_top:Test', 'output_ecfp:Test', 'output_fcfp:Test', 'output_pub:Test',], :]
subset_dt_ext1 = data_dt.loc[['output_maccs:Ext1', 'output_top:Ext1', 'output_ecfp:Ext1', 'output_fcfp:Ext1', 'output_pub:Ext1',], :]
subset_dt_ext2 = data_dt.loc[['output_maccs:Ext2', 'output_top:Ext2', 'output_ecfp:Ext2', 'output_fcfp:Ext2', 'output_pub:Ext2',], :]
subset_dt_ext3 = data_dt.loc[['output_maccs:Ext3', 'output_top:Ext3', 'output_ecfp:Ext3', 'output_fcfp:Ext3', 'output_pub:Ext3',], :]

# %% [markdown]
# # RF

# %%
#Reading in grep files
grep_rf = pd.read_csv('grep_rf.txt', sep = '\t')
grep_rf = grep_rf.T
grep_rf = grep_rf.reset_index()
grep_rf = grep_rf.T
grep_rf = grep_rf.reset_index(drop = True)

#converting to str (rf)
grep_rf = grep_rf.astype(str)

#splitting scores 
str_split_rf = grep_rf[1].tolist()
i = 0
while (i < len(str_split_rf)):
    str_split_rf[i] = str_split_rf[i].split()
    i = i + 1
    
#making df
scores_rf = pd.DataFrame(str_split_rf)

#label df
labels_rf = pd.DataFrame(grep_rf[0])
labels_rf = labels_rf.rename(columns = {0 : 'labels'})

#combining
data_rf = pd.concat([labels_rf, scores_rf], axis = 1)

#reindexing
data_rf = data_rf.rename(columns = {0 : 'ACC', 1 : 'AUC', 2 : 'MCC', 3 : 'SENS', 4 : 'SPHE', 5 : 'BACC',})
data_rf = data_rf.set_index('labels')

#seperating datasets into Train, Test, Ext1, Ext2, Ext3
data_rf = data_rf.iloc[:25]
data_rf.loc['output_maccs:Test']
subset_rf_train = data_rf.loc[['output_maccs:Train', 'output_top:Train', 'output_ecfp:Train', 'output_fcfp:Train', 'output_pub:Train',], :]
subset_rf_test = data_rf.loc[['output_maccs:Test', 'output_top:Test', 'output_ecfp:Test', 'output_fcfp:Test', 'output_pub:Test',], :]
subset_rf_ext1 = data_rf.loc[['output_maccs:Ext1', 'output_top:Ext1', 'output_ecfp:Ext1', 'output_fcfp:Ext1', 'output_pub:Ext1',], :]
subset_rf_ext2 = data_rf.loc[['output_maccs:Ext2', 'output_top:Ext2', 'output_ecfp:Ext2', 'output_fcfp:Ext2', 'output_pub:Ext2',], :]
subset_rf_ext3 = data_rf.loc[['output_maccs:Ext3', 'output_top:Ext3', 'output_ecfp:Ext3', 'output_fcfp:Ext3', 'output_pub:Ext3',], :]

# %% [markdown]
# # KNN

# %%
#Reading in grep files
grep_knn = pd.read_csv('grep_knn.txt', sep = '\t')
grep_knn = grep_knn.T
grep_knn = grep_knn.reset_index()
grep_knn = grep_knn.T
grep_knn = grep_knn.reset_index(drop = True)

#converting to str (knn)
grep_knn = grep_knn.astype(str)

#splitting scores 
str_split_knn = grep_knn[1].tolist()
i = 0
while (i < len(str_split_knn)):
    str_split_knn[i] = str_split_knn[i].split()
    i = i + 1
    
#making df
scores_knn = pd.DataFrame(str_split_knn)

#label df
labels_knn = pd.DataFrame(grep_knn[0])
labels_knn = labels_knn.rename(columns = {0 : 'labels'})

#combining
data_knn = pd.concat([labels_knn, scores_knn], axis = 1)

#reindexing
data_knn = data_knn.rename(columns = {0 : 'ACC', 1 : 'AUC', 2 : 'MCC', 3 : 'SENS', 4 : 'SPHE', 5 : 'BACC',})
data_knn = data_knn.set_index('labels')

#seperating datasets into Train, Test, Ext1, Ext2, Ext3
data_knn = data_knn.iloc[:25]
data_knn.loc['output_maccs:Test']
subset_knn_train = data_knn.loc[['output_maccs:Train', 'output_top:Train', 'output_ecfp:Train', 'output_fcfp:Train', 'output_pub:Train',], :]
subset_knn_test = data_knn.loc[['output_maccs:Test', 'output_top:Test', 'output_ecfp:Test', 'output_fcfp:Test', 'output_pub:Test',], :]
subset_knn_ext1 = data_knn.loc[['output_maccs:Ext1', 'output_top:Ext1', 'output_ecfp:Ext1', 'output_fcfp:Ext1', 'output_pub:Ext1',], :]
subset_knn_ext2 = data_knn.loc[['output_maccs:Ext2', 'output_top:Ext2', 'output_ecfp:Ext2', 'output_fcfp:Ext2', 'output_pub:Ext2',], :]
subset_knn_ext3 = data_knn.loc[['output_maccs:Ext3', 'output_top:Ext3', 'output_ecfp:Ext3', 'output_fcfp:Ext3', 'output_pub:Ext3',], :]

# %% [markdown]
# # SVM

# %%
#Reading in grep files
grep_svm = pd.read_csv('grep_svm.txt', sep = '\t')
grep_svm = grep_svm.T
grep_svm = grep_svm.reset_index()
grep_svm = grep_svm.T
grep_svm = grep_svm.reset_index(drop = True)

#converting to str (svm)
grep_svm = grep_svm.astype(str)

#splitting scores 
str_split_svm = grep_svm[1].tolist()
i = 0
while (i < len(str_split_svm)):
    str_split_svm[i] = str_split_svm[i].split()
    i = i + 1
    
#making df
scores_svm = pd.DataFrame(str_split_svm)

#label df
labels_svm = pd.DataFrame(grep_svm[0])
labels_svm = labels_svm.rename(columns = {0 : 'labels'})

#combining
data_svm = pd.concat([labels_svm, scores_svm], axis = 1)

#reindexing
data_svm = data_svm.rename(columns = {0 : 'ACC', 1 : 'AUC', 2 : 'MCC', 3 : 'SENS', 4 : 'SPHE', 5 : 'BACC',})
data_svm = data_svm.set_index('labels')

#seperating datasets into Train, Test, Ext1, Ext2, Ext3
data_svm = data_svm.iloc[:25]
data_svm.loc['output_maccs:Test']
subset_svm_train = data_svm.loc[['output_maccs:Train', 'output_top:Train', 'output_ecfp:Train', 'output_fcfp:Train', 'output_pub:Train',], :]
subset_svm_test = data_svm.loc[['output_maccs:Test', 'output_top:Test', 'output_ecfp:Test', 'output_fcfp:Test', 'output_pub:Test',], :]
subset_svm_ext1 = data_svm.loc[['output_maccs:Ext1', 'output_top:Ext1', 'output_ecfp:Ext1', 'output_fcfp:Ext1', 'output_pub:Ext1',], :]
subset_svm_ext2 = data_svm.loc[['output_maccs:Ext2', 'output_top:Ext2', 'output_ecfp:Ext2', 'output_fcfp:Ext2', 'output_pub:Ext2',], :]
subset_svm_ext3 = data_svm.loc[['output_maccs:Ext3', 'output_top:Ext3', 'output_ecfp:Ext3', 'output_fcfp:Ext3', 'output_pub:Ext3',], :]

# %% [markdown]
# # NN

# %%
#Reading in grep files
grep_nn = pd.read_csv('grep_nn.txt', sep = '\t')
grep_nn = grep_nn.T
grep_nn = grep_nn.reset_index()
grep_nn = grep_nn.T
grep_nn = grep_nn.reset_index(drop = True)

#converting to str (nn)
grep_nn = grep_nn.astype(str)

#splitting scores 
str_split_nn = grep_nn[1].tolist()
i = 0
while (i < len(str_split_nn)):
    str_split_nn[i] = str_split_nn[i].split()
    i = i + 1
    
#making df
scores_nn = pd.DataFrame(str_split_nn)

#label df
labels_nn = pd.DataFrame(grep_nn[0])
labels_nn = labels_nn.rename(columns = {0 : 'labels'})

#combining
data_nn = pd.concat([labels_nn, scores_nn], axis = 1)

#reindexing
data_nn = data_nn.rename(columns = {0 : 'ACC', 1 : 'AUC', 2 : 'MCC', 3 : 'SENS', 4 : 'SPHE', 5 : 'BACC',})
data_nn = data_nn.set_index('labels')

#seperating datasets into Train, Test, Ext1, Ext2, Ext3
data_nn = data_nn.iloc[:25]
data_nn.loc['output_maccs:Test']
subset_nn_train = data_nn.loc[['output_maccs:Train', 'output_top:Train', 'output_ecfp:Train', 'output_fcfp:Train', 'output_pub:Train',], :]
subset_nn_test = data_nn.loc[['output_maccs:Test', 'output_top:Test', 'output_ecfp:Test', 'output_fcfp:Test', 'output_pub:Test',], :]
subset_nn_ext1 = data_nn.loc[['output_maccs:Ext1', 'output_top:Ext1', 'output_ecfp:Ext1', 'output_fcfp:Ext1', 'output_pub:Ext1',], :]
subset_nn_ext2 = data_nn.loc[['output_maccs:Ext2', 'output_top:Ext2', 'output_ecfp:Ext2', 'output_fcfp:Ext2', 'output_pub:Ext2',], :]
subset_nn_ext3 = data_nn.loc[['output_maccs:Ext3', 'output_top:Ext3', 'output_ecfp:Ext3', 'output_fcfp:Ext3', 'output_pub:Ext3',], :]

# %% [markdown]
# # Combining Dataframes

# %%
#combining auc for tests
auc_nb_test = subset_nb_test['AUC']
auc_dt_test = subset_dt_test['AUC']
auc_rf_test = subset_rf_test['AUC']
auc_knn_test = subset_knn_test['AUC']
auc_svm_test = subset_svm_test['AUC']
auc_nn_test = subset_nn_test['AUC']
auc_all_test = pd.concat([auc_nb_test, auc_dt_test, auc_rf_test, auc_knn_test, auc_svm_test, auc_svm_test], axis = 1)
auc_all_test.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
auc_all_test['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
auc_all_test = auc_all_test.set_index('FPs')
auc_all_test = auc_all_test.astype(float)

# %%
#combining auc for ext1
auc_nb_ext1 = subset_nb_ext1['AUC']
auc_dt_ext1 = subset_dt_ext1['AUC']
auc_rf_ext1 = subset_rf_ext1['AUC']
auc_knn_ext1 = subset_knn_ext1['AUC']
auc_svm_ext1 = subset_svm_ext1['AUC']
auc_nn_ext1 = subset_nn_ext1['AUC']
auc_all_ext1 = pd.concat([auc_nb_ext1, auc_dt_ext1, auc_rf_ext1, auc_knn_ext1, auc_svm_ext1, auc_svm_ext1], axis = 1)
auc_all_ext1.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
auc_all_ext1['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
auc_all_ext1 = auc_all_ext1.set_index('FPs')
auc_all_ext1 = auc_all_ext1.astype(float)

# %%
#combining auc for ext2
auc_nb_ext2 = subset_nb_ext2['AUC']
auc_dt_ext2 = subset_dt_ext2['AUC']
auc_rf_ext2 = subset_rf_ext2['AUC']
auc_knn_ext2 = subset_knn_ext2['AUC']
auc_svm_ext2 = subset_svm_ext2['AUC']
auc_nn_ext2 = subset_nn_ext2['AUC']
auc_all_ext2 = pd.concat([auc_nb_ext2, auc_dt_ext2, auc_rf_ext2, auc_knn_ext2, auc_svm_ext2, auc_svm_ext2], axis = 1)
auc_all_ext2.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
auc_all_ext2['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
auc_all_ext2 = auc_all_ext2.set_index('FPs')
auc_all_ext2 = auc_all_ext2.astype(float)

# %%
#combining auc for ext3
auc_nb_ext3 = subset_nb_ext3['AUC']
auc_dt_ext3 = subset_dt_ext3['AUC']
auc_rf_ext3 = subset_rf_ext3['AUC']
auc_knn_ext3 = subset_knn_ext3['AUC']
auc_svm_ext3 = subset_svm_ext3['AUC']
auc_nn_ext3 = subset_nn_ext3['AUC']
auc_all_ext3 = pd.concat([auc_nb_ext3, auc_dt_ext3, auc_rf_ext3, auc_knn_ext3, auc_svm_ext3, auc_svm_ext3], axis = 1)
auc_all_ext3.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
auc_all_ext3['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
auc_all_ext3 = auc_all_ext3.set_index('FPs')
auc_all_ext3 = auc_all_ext3.astype(float)

# %%
#combining bacc for tests
bacc_nb_test = subset_nb_test['BACC']
bacc_dt_test = subset_dt_test['BACC']
bacc_rf_test = subset_rf_test['BACC']
bacc_knn_test = subset_knn_test['BACC']
bacc_svm_test = subset_svm_test['BACC']
bacc_nn_test = subset_nn_test['BACC']
bacc_all_test = pd.concat([bacc_nb_test, bacc_dt_test, bacc_rf_test, bacc_knn_test, bacc_svm_test, bacc_svm_test], axis = 1)
bacc_all_test.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
bacc_all_test['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
bacc_all_test = bacc_all_test.set_index('FPs')
bacc_all_test = bacc_all_test.astype(float)

# %%
#combining bacc for ext1s
bacc_nb_ext1 = subset_nb_ext1['BACC']
bacc_dt_ext1 = subset_dt_ext1['BACC']
bacc_rf_ext1 = subset_rf_ext1['BACC']
bacc_knn_ext1 = subset_knn_ext1['BACC']
bacc_svm_ext1 = subset_svm_ext1['BACC']
bacc_nn_ext1 = subset_nn_ext1['BACC']
bacc_all_ext1 = pd.concat([bacc_nb_ext1, bacc_dt_ext1, bacc_rf_ext1, bacc_knn_ext1, bacc_svm_ext1, bacc_svm_ext1], axis = 1)
bacc_all_ext1.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
bacc_all_ext1['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
bacc_all_ext1 = bacc_all_ext1.set_index('FPs')
bacc_all_ext1 = bacc_all_ext1.astype(float)

# %%
#combining bacc for ext2s
bacc_nb_ext2 = subset_nb_ext2['BACC']
bacc_dt_ext2 = subset_dt_ext2['BACC']
bacc_rf_ext2 = subset_rf_ext2['BACC']
bacc_knn_ext2 = subset_knn_ext2['BACC']
bacc_svm_ext2 = subset_svm_ext2['BACC']
bacc_nn_ext2 = subset_nn_ext2['BACC']
bacc_all_ext2 = pd.concat([bacc_nb_ext2, bacc_dt_ext2, bacc_rf_ext2, bacc_knn_ext2, bacc_svm_ext2, bacc_svm_ext2], axis = 1)
bacc_all_ext2.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
bacc_all_ext2['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
bacc_all_ext2 = bacc_all_ext2.set_index('FPs')
bacc_all_ext2 = bacc_all_ext2.astype(float)

# %%
#combining sens for tests
sens_nb_test = subset_nb_test['SENS']
sens_dt_test = subset_dt_test['SENS']
sens_rf_test = subset_rf_test['SENS']
sens_knn_test = subset_knn_test['SENS']
sens_svm_test = subset_svm_test['SENS']
sens_nn_test = subset_nn_test['SENS']
sens_all_test = pd.concat([sens_nb_test, sens_dt_test, sens_rf_test, sens_knn_test, sens_svm_test, sens_svm_test], axis = 1)
sens_all_test.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
sens_all_test['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
sens_all_test = sens_all_test.set_index('FPs')
sens_all_test = sens_all_test.astype(float)

# %%
#combining sens for ext1s
sens_nb_ext1 = subset_nb_ext1['SENS']
sens_dt_ext1 = subset_dt_ext1['SENS']
sens_rf_ext1 = subset_rf_ext1['SENS']
sens_knn_ext1 = subset_knn_ext1['SENS']
sens_svm_ext1 = subset_svm_ext1['SENS']
sens_nn_ext1 = subset_nn_ext1['SENS']
sens_all_ext1 = pd.concat([sens_nb_ext1, sens_dt_ext1, sens_rf_ext1, sens_knn_ext1, sens_svm_ext1, sens_svm_ext1], axis = 1)
sens_all_ext1.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
sens_all_ext1['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
sens_all_ext1 = sens_all_ext1.set_index('FPs')
sens_all_ext1 = sens_all_ext1.astype(float)

# %%
#combining sphe for ext1s
sphe_nb_ext1 = subset_nb_ext1['SPHE']
sphe_dt_ext1 = subset_dt_ext1['SPHE']
sphe_rf_ext1 = subset_rf_ext1['SPHE']
sphe_knn_ext1 = subset_knn_ext1['SPHE']
sphe_svm_ext1 = subset_svm_ext1['SPHE']
sphe_nn_ext1 = subset_nn_ext1['SPHE']
sphe_all_ext1 = pd.concat([sphe_nb_ext1, sphe_dt_ext1, sphe_rf_ext1, sphe_knn_ext1, sphe_svm_ext1, sphe_svm_ext1], axis = 1)
sphe_all_ext1.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
sphe_all_ext1['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
sphe_all_ext1 = sphe_all_ext1.set_index('FPs')
sphe_all_ext1 = sphe_all_ext1.astype(float)

# %%
#combining sphe for tests
sphe_nb_test = subset_nb_test['SPHE']
sphe_dt_test = subset_dt_test['SPHE']
sphe_rf_test = subset_rf_test['SPHE']
sphe_knn_test = subset_knn_test['SPHE']
sphe_svm_test = subset_svm_test['SPHE']
sphe_nn_test = subset_nn_test['SPHE']
sphe_all_test = pd.concat([sphe_nb_test, sphe_dt_test, sphe_rf_test, sphe_knn_test, sphe_svm_test, sphe_svm_test], axis = 1)
sphe_all_test.columns = ['Naive Bayes', 'Decision Tree', 'Random Forest', 'K Nearest Neighbors', 'Support Vector Machine', 'Neural Network']
sphe_all_test['FPs'] = ['Maccs', 'Topological', 'Morgan ECFP', 'Morgan FCFP', 'PubChem']
sphe_all_test = sphe_all_test.set_index('FPs')
sphe_all_test = sphe_all_test.astype(float)

# %% [markdown]
# # Making Heatmaps

# %%
sns.heatmap(bacc_all_ext2, annot = True, cmap = cm.YlGnBu, vmin = .50, vmax = 1)

# %%
sns.heatmap(sens_all_ext1, annot = True, cmap = cm.YlGnBu, vmin = .65, vmax = 1)

# %%
plt.figure(figsize = (9, 3))
sns.heatmap(sens_all_test, annot = True, cmap = cm.YlGnBu, vmin = .55, vmax = 1, )

# %%
f = plt.figure(figsize = (9, 3))
sns.heatmap(sens_all_test, annot = True, cmap = cm.YlGnBu, vmin = 0.55, vmax = 1)

f.savefig("sens_test.png", bbox_inches='tight', dpi=600)

# %%
sns.heatmap(auc_all_ext1, annot = True, cmap = cm.Reds)

# %%
sns.heatmap(auc_all_ext2, annot = True, cmap = cm.Reds)

# %%
sns.heatmap(auc_all_ext3, annot = True, cmap = cm.Reds)
